# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import os
import keras
from keras_unet.models import custom_unet
# Out:
# 2023-02-02 00:04:06.273702: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# -----------------------------------------
# keras-unet init: TF version is >= 2.0.0 - using `tf.keras` instead of `Keras`
# -----------------------------------------

# %%
DATAPATH = '/raid/mpsych/CACTAS/DATA/Nathan Arnett Calcification'
images_file = os.path.join(DATAPATH, 'images.npy')
labels_file = os.path.join(DATAPATH, 'labels.npy')

# %%
images = np.load(images_file)
labels = np.load(labels_file)

# %%
# full dataset does not have the last channel
images = images.reshape(images.shape[0],images.shape[1],images.shape[2],1)
labels = labels.reshape(labels.shape[0],labels.shape[1],labels.shape[2],1)

# %%
p = np.random.permutation(len(images))

# %%
images = images[p]
labels = labels[p]

# %%
images = images.astype(np.float64)
labels = labels.astype(np.float64)

# %%
for i in range(images.shape[0]):
    
    images[i] = (images[i] - images[i].min()) / (images[i].max() - images[i].min()) # normalize individually

# %%
images.shape
# Out:
# (503, 512, 512, 1)

# %%
labels.shape
# Out:
# (503, 512, 512, 1)

# %%
from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=images, mask_imgs=labels, nm_img_to_plot=3, figsize=5)

# %%
X_train = images[0:300]
y_train = labels[0:300]
X_val = images[300:400]
y_val = labels[300:400]
X_test = images[400:]
y_test = labels[400:]

# %%
from keras_unet.utils import get_augmented

train_gen = get_augmented(
    X_train, y_train, batch_size=2,
    data_gen_args = dict(
        rotation_range=5.,
        width_shift_range=0.05,
        height_shift_range=0.05,
        shear_range=40,
        zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='constant'
    ))

# %%
sample_batch = next(train_gen)
xx, yy = sample_batch
print(xx.shape, yy.shape)
from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=xx, mask_imgs=yy, nm_img_to_plot=2, figsize=6)
# Out:
# (2, 512, 512, 1) (2, 512, 512, 1)

# %%
from keras_unet_collection import models, losses
import torch

model = models.swin_unet_2d((512, 512, 1), filter_num_begin=64,
                               n_labels=1, depth=4, stack_num_down=4, stack_num_up=4,
                               patch_size=(4, 4), num_heads=[4, 8, 16, 16],
                               window_size=[4, 4, 4, 4], num_mlp=512, 
                               output_activation='Sigmoid', shift_window=True, name='swin_unet')

#Softmax
# Out:
# 2023-02-02 00:04:51.717341: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-02-02 00:04:51.823315: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:87:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2023-02-02 00:04:51.823349: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-02-02 00:04:51.823379: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-02-02 00:04:51.823394: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-02-02 00:04:51.824413: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-02-02 00:04:51.824805: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-02-02 00:04:51.825365: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-02-02 00:04:51.826162: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-02-02 00:04:51.826191: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-02-02 00:04:51.834941: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-02-02 00:04:51.835610: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-02 00:04:51.840001: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:87:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2023-02-02 00:04:51.848509: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-02-02 00:04:51.848534: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-02-02 00:04:52.457811: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-02-02 00:04:52.457852: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-02-02 00:04:52.457858: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-02-02 00:04:52.470546: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 38425 MB memory) -> physical GPU (device: 0, name: A100-SXM4-40GB, pci bus id: 0000:87:00.0, compute capability: 8.0)
# WARNING:tensorflow:From /home/jiehyun.kim001/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.

# %%
model.summary()
# Out:
# Model: "swin_unet_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# patch_extract (patch_extract)   (None, 16384, 16)    0           input_1[0][0]
# __________________________________________________________________________________________________
# patch_embedding (patch_embeddin (None, 16384, 64)    1049664     patch_extract[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block (SwinTra (None, 16384, 64)    83460       patch_embedding[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_1 (SwinT (None, 16384, 64)    345604      swin_transformer_block[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_2 (SwinT (None, 16384, 64)    83460       swin_transformer_block_1[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_3 (SwinT (None, 16384, 64)    345604      swin_transformer_block_2[0][0]
# __________________________________________________________________________________________________
# patch_merging (patch_merging)   (None, 4096, 128)    32768       swin_transformer_block_3[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_4 (SwinT (None, 4096, 128)    198920      patch_merging[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_5 (SwinT (None, 4096, 128)    264456      swin_transformer_block_4[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_6 (SwinT (None, 4096, 128)    198920      swin_transformer_block_5[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_7 (SwinT (None, 4096, 128)    264456      swin_transformer_block_6[0][0]
# __________________________________________________________________________________________________
# patch_merging_1 (patch_merging) (None, 1024, 256)    131072      swin_transformer_block_7[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_8 (SwinT (None, 1024, 256)    528144      patch_merging_1[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_9 (SwinT (None, 1024, 256)    544528      swin_transformer_block_8[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_10 (Swin (None, 1024, 256)    528144      swin_transformer_block_9[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_11 (Swin (None, 1024, 256)    544528      swin_transformer_block_10[0][0]
# __________________________________________________________________________________________________
# patch_merging_2 (patch_merging) (None, 256, 512)     524288      swin_transformer_block_11[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_12 (Swin (None, 256, 512)     1579024     patch_merging_2[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_13 (Swin (None, 256, 512)     1583120     swin_transformer_block_12[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_14 (Swin (None, 256, 512)     1579024     swin_transformer_block_13[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_15 (Swin (None, 256, 512)     1583120     swin_transformer_block_14[0][0]
# __________________________________________________________________________________________________
# patch_expanding (patch_expandin (None, 1024, 256)    524288      swin_transformer_block_15[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_0 (Concatenate (None, 1024, 512)    0           patch_expanding[0][0]
#                                                                  swin_transformer_block_11[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_linear_proj_0  (None, 1024, 256)    131072      swin_unet_concat_0[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_16 (Swin (None, 1024, 256)    528144      swin_unet_concat_linear_proj_0[0]
# __________________________________________________________________________________________________
# swin_transformer_block_17 (Swin (None, 1024, 256)    544528      swin_transformer_block_16[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_18 (Swin (None, 1024, 256)    528144      swin_transformer_block_17[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_19 (Swin (None, 1024, 256)    544528      swin_transformer_block_18[0][0]
# __________________________________________________________________________________________________
# patch_expanding_1 (patch_expand (None, 4096, 128)    131072      swin_transformer_block_19[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_1 (Concatenate (None, 4096, 256)    0           patch_expanding_1[0][0]
#                                                                  swin_transformer_block_7[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_linear_proj_1  (None, 4096, 128)    32768       swin_unet_concat_1[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_20 (Swin (None, 4096, 128)    199312      swin_unet_concat_linear_proj_1[0]
# __________________________________________________________________________________________________
# swin_transformer_block_21 (Swin (None, 4096, 128)    264848      swin_transformer_block_20[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_22 (Swin (None, 4096, 128)    199312      swin_transformer_block_21[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_23 (Swin (None, 4096, 128)    264848      swin_transformer_block_22[0][0]
# __________________________________________________________________________________________________
# patch_expanding_2 (patch_expand (None, 16384, 64)    32768       swin_transformer_block_23[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_2 (Concatenate (None, 16384, 128)   0           patch_expanding_2[0][0]
#                                                                  swin_transformer_block_3[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_linear_proj_2  (None, 16384, 64)    8192        swin_unet_concat_2[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_24 (Swin (None, 16384, 64)    83656       swin_unet_concat_linear_proj_2[0]
# __________________________________________________________________________________________________
# swin_transformer_block_25 (Swin (None, 16384, 64)    345800      swin_transformer_block_24[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_26 (Swin (None, 16384, 64)    83656       swin_transformer_block_25[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_27 (Swin (None, 16384, 64)    345800      swin_transformer_block_26[0][0]
# __________________________________________________________________________________________________
# patch_expanding_3 (patch_expand (None, 512, 512, 16) 16384       swin_transformer_block_27[0][0]
# __________________________________________________________________________________________________
# swin_unet_output (Conv2D)       (None, 512, 512, 1)  17          patch_expanding_3[0][0]
# __________________________________________________________________________________________________
# swin_unet_output_activation (Ac (None, 512, 512, 1)  0           swin_unet_output[0][0]
# ==================================================================================================
# Total params: 16,801,441
# Trainable params: 15,409,825
# Non-trainable params: 1,391,616
# __________________________________________________________________________________________________

# %%
from tensorflow.keras import optimizers
#from tensorflow.keras.optimizers import Adam
from keras_unet.metrics import iou, iou_thresholded, dice_coef
from keras_unet_collection import losses
#from keras_unet.losses import jaccard_distance

# %%
model.compile(loss='binary_crossentropy',
              #loss=jaccard_distance,
              optimizer=optimizers.Adam(lr=1e-3),
              #optimizer = 'Adam',
              metrics=[iou, iou_thresholded])
# Out:
# /home/jiehyun.kim001/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %%
history = model.fit(#X_train, 
                    #y_train,
                    train_gen,
                    steps_per_epoch=50,
                    epochs=200,
                    #batch_size=16, 
                    #epochs=200,
                    validation_data=(X_val, y_val))
# Out:
# Epoch 1/200
# 50/50 [==============================] - 12s 239ms/step - loss: 0.0019 - iou: 0.0076 - iou_thresholded: 0.0161 - val_loss: 0.0023 - val_iou: 0.0018 - val_iou_thresholded: 0.0019
# Epoch 2/200
# 50/50 [==============================] - 12s 235ms/step - loss: 0.0020 - iou: 0.0073 - iou_thresholded: 0.0139 - val_loss: 0.0024 - val_iou: 0.0019 - val_iou_thresholded: 0.0019
# Epoch 3/200
# 50/50 [==============================] - 12s 236ms/step - loss: 0.0020 - iou: 0.0072 - iou_thresholded: 0.0159 - val_loss: 0.0021 - val_iou: 0.0020 - val_iou_thresholded: 0.0019
# Epoch 4/200
# 50/50 [==============================] - 12s 241ms/step - loss: 0.0018 - iou: 0.0061 - iou_thresholded: 0.0197 - val_loss: 0.0018 - val_iou: 0.0026 - val_iou_thresholded: 0.0019
# Epoch 5/200
# 50/50 [==============================] - 12s 235ms/step - loss: 0.0024 - iou: 0.0074 - iou_thresholded: 0.0114 - val_loss: 0.0021 - val_iou: 0.0023 - val_iou_thresholded: 0.0019
# Epoch 6/200
# 50/50 [==============================] - 12s 235ms/step - loss: 0.0018 - iou: 0.0061 - iou_thresholded: 0.0180 - val_loss: 0.0018 - val_iou: 0.0030 - val_iou_thresholded: 0.0019
# Epoch 7/200
# 50/50 [==============================] - 12s 236ms/step - loss: 0.0016 - iou: 0.0069 - iou_thresholded: 0.0136 - val_loss: 0.0019 - val_iou: 0.0041 - val_iou_thresholded: 0.0019
# Epoch 8/200
# 50/50 [==============================] - 12s 239ms/step - loss: 0.0020 - iou: 0.0064 - iou_thresholded: 0.0154 - val_loss: 0.0018 - val_iou: 0.0028 - val_iou_thresholded: 0.0019
# Epoch 9/200
# 50/50 [==============================] - 12s 236ms/step - loss: 0.0015 - iou: 0.0081 - iou_thresholded: 0.0197 - val_loss: 0.0018 - val_iou: 0.0031 - val_iou_thresholded: 0.0019
# Epoch 10/200
# 50/50 [==============================] - 12s 235ms/step - loss: 0.0018 - iou: 0.0085 - iou_thresholded: 0.0178 - val_loss: 0.0017 - val_iou: 0.0057 - val_iou_thresholded: 0.0019
# Epoch 11/200
# 50/50 [==============================] - 12s 239ms/step - loss: 0.0020 - iou: 0.0075 - iou_thresholded: 0.0101 - val_loss: 0.0016 - val_iou: 0.0054 - val_iou_thresholded: 0.0019
# Epoch 12/200
# 50/50 [==============================] - 12s 233ms/step - loss: 0.0018 - iou: 0.0078 - iou_thresholded: 0.0146 - val_loss: 0.0016 - val_iou: 0.0087 - val_iou_thresholded: 0.0019
# Epoch 13/200
# 50/50 [==============================] - 12s 236ms/step - loss: 0.0015 - iou: 0.0099 - iou_thresholded: 0.0209 - val_loss: 0.0015 - val_iou: 0.0169 - val_iou_thresholded: 0.0035
# Epoch 14/200
# 50/50 [==============================] - 12s 239ms/step - loss: 0.0016 - iou: 0.0139 - iou_thresholded: 0.0207 - val_loss: 0.0021 - val_iou: 0.0029 - val_iou_thresholded: 0.0019
# Epoch 15/200
# 50/50 [==============================] - 12s 237ms/step - loss: 0.0016 - iou: 0.0124 - iou_thresholded: 0.0193 - val_loss: 0.0015 - val_iou: 0.0176 - val_iou_thresholded: 0.0027
# Epoch 16/200
# 50/50 [==============================] - 12s 236ms/step - loss: 0.0016 - iou: 0.0171 - iou_thresholded: 0.0238 - val_loss: 0.0019 - val_iou: 0.0045 - val_iou_thresholded: 0.0019
# Epoch 17/200
# 50/50 [==============================] - 12s 234ms/step - loss: 0.0017 - iou: 0.0215 - iou_thresholded: 0.0260 - val_loss: 0.0014 - val_iou: 0.0387 - val_iou_thresholded: 0.0223
# Epoch 18/200
# 50/50 [==============================] - 12s 239ms/step - loss: 0.0016 - iou: 0.0319 - iou_thresholded: 0.0289 - val_loss: 0.0015 - val_iou: 0.0449 - val_iou_thresholded: 0.0283
# Epoch 19/200
# 50/50 [==============================] - 12s 233ms/step - loss: 0.0012 - iou: 0.0331 - iou_thresholded: 0.0343 - val_loss: 0.0014 - val_iou: 0.0362 - val_iou_thresholded: 0.0366
# Epoch 20/200
# 50/50 [==============================] - 12s 238ms/step - loss: 0.0014 - iou: 0.0294 - iou_thresholded: 0.0260 - val_loss: 0.0013 - val_iou: 0.0735 - val_iou_thresholded: 0.0629
# Epoch 21/200
# 50/50 [==============================] - 12s 240ms/step - loss: 0.0013 - iou: 0.0440 - iou_thresholded: 0.0638 - val_loss: 0.0012 - val_iou: 0.0622 - val_iou_thresholded: 0.0630
# Epoch 22/200
# 50/50 [==============================] - 12s 235ms/step - loss: 0.0013 - iou: 0.0519 - iou_thresholded: 0.0680 - val_loss: 0.0012 - val_iou: 0.0785 - val_iou_thresholded: 0.0985
# Epoch 23/200
# 50/50 [==============================] - 12s 235ms/step - loss: 0.0013 - iou: 0.0420 - iou_thresholded: 0.0389 - val_loss: 0.0012 - val_iou: 0.1046 - val_iou_thresholded: 0.1600
# Epoch 24/200
# 50/50 [==============================] - 12s 241ms/step - loss: 0.0014 - iou: 0.0483 - iou_thresholded: 0.0589 - val_loss: 0.0012 - val_iou: 0.0692 - val_iou_thresholded: 0.0670
# Epoch 25/200
# 50/50 [==============================] - 12s 235ms/step - loss: 0.0012 - iou: 0.0439 - iou_thresholded: 0.0533 - val_loss: 0.0012 - val_iou: 0.0602 - val_iou_thresholded: 0.0142
# Epoch 26/200
# 50/50 [==============================] - 12s 237ms/step - loss: 0.0013 - iou: 0.0515 - iou_thresholded: 0.0573 - val_loss: 0.0012 - val_iou: 0.1071 - val_iou_thresholded: 0.2428
# Epoch 27/200
# 50/50 [==============================] - 12s 236ms/step - loss: 0.0012 - iou: 0.0543 - iou_thresholded: 0.0639 - val_loss: 0.0012 - val_iou: 0.1215 - val_iou_thresholded: 0.2488
# Epoch 28/200
# 50/50 [==============================] - 12s 238ms/step - loss: 0.0011 - iou: 0.0579 - iou_thresholded: 0.0842 - val_loss: 0.0012 - val_iou: 0.0618 - val_iou_thresholded: 0.0236
# Epoch 29/200
# 50/50 [==============================] - 12s 234ms/step - loss: 0.0012 - iou: 0.0533 - iou_thresholded: 0.0576 - val_loss: 0.0010 - val_iou: 0.1173 - val_iou_thresholded: 0.1330
# Epoch 30/200
# 50/50 [==============================] - 12s 236ms/step - loss: 0.0011 - iou: 0.0540 - iou_thresholded: 0.0702 - val_loss: 0.0011 - val_iou: 0.0897 - val_iou_thresholded: 0.0771
# Epoch 31/200
# 50/50 [==============================] - 12s 236ms/step - loss: 0.0011 - iou: 0.0582 - iou_thresholded: 0.0641 - val_loss: 0.0011 - val_iou: 0.0880 - val_iou_thresholded: 0.0992
# Epoch 32/200
# 50/50 [==============================] - 12s 240ms/step - loss: 0.0012 - iou: 0.0820 - iou_thresholded: 0.1042 - val_loss: 0.0010 - val_iou: 0.1074 - val_iou_thresholded: 0.1730
# Epoch 33/200
# 50/50 [==============================] - 12s 236ms/step - loss: 0.0012 - iou: 0.0708 - iou_thresholded: 0.0995 - val_loss: 0.0012 - val_iou: 0.0794 - val_iou_thresholded: 0.1847
# Epoch 34/200
# 50/50 [==============================] - 12s 235ms/step - loss: 0.0012 - iou: 0.0518 - iou_thresholded: 0.0427 - val_loss: 0.0011 - val_iou: 0.0825 - val_iou_thresholded: 0.1191
# Epoch 35/200
# 50/50 [==============================] - 12s 237ms/step - loss: 9.1829e-04 - iou: 0.0806 - iou_thresholded: 0.0827 - val_loss: 9.7766e-04 - val_iou: 0.1521 - val_iou_thresholded: 0.2157
# Epoch 36/200
# 50/50 [==============================] - 12s 234ms/step - loss: 8.9140e-04 - iou: 0.0938 - iou_thresholded: 0.1215 - val_loss: 0.0010 - val_iou: 0.1238 - val_iou_thresholded: 0.1410
# Epoch 37/200
# 50/50 [==============================] - 12s 233ms/step - loss: 0.0011 - iou: 0.0652 - iou_thresholded: 0.0785 - val_loss: 9.8164e-04 - val_iou: 0.1007 - val_iou_thresholded: 0.1314
# Epoch 38/200
# 50/50 [==============================] - 12s 235ms/step - loss: 0.0012 - iou: 0.0618 - iou_thresholded: 0.0669 - val_loss: 0.0011 - val_iou: 0.0610 - val_iou_thresholded: 0.0323
# Epoch 39/200
# 50/50 [==============================] - 12s 240ms/step - loss: 0.0013 - iou: 0.0570 - iou_thresholded: 0.0705 - val_loss: 0.0013 - val_iou: 0.0321 - val_iou_thresholded: 0.0084
# Epoch 40/200
# 50/50 [==============================] - 12s 235ms/step - loss: 0.0012 - iou: 0.0465 - iou_thresholded: 0.0578 - val_loss: 0.0010 - val_iou: 0.0902 - val_iou_thresholded: 0.1112
# Epoch 41/200
# 50/50 [==============================] - 12s 234ms/step - loss: 0.0010 - iou: 0.0714 - iou_thresholded: 0.0831 - val_loss: 9.9007e-04 - val_iou: 0.1216 - val_iou_thresholded: 0.1459
# Epoch 42/200
# 50/50 [==============================] - 12s 238ms/step - loss: 0.0011 - iou: 0.0907 - iou_thresholded: 0.1115 - val_loss: 9.5946e-04 - val_iou: 0.1079 - val_iou_thresholded: 0.1454
# Epoch 43/200
# 50/50 [==============================] - 12s 236ms/step - loss: 9.3228e-04 - iou: 0.0812 - iou_thresholded: 0.0848 - val_loss: 0.0013 - val_iou: 0.0471 - val_iou_thresholded: 0.0099
# Epoch 44/200
# 50/50 [==============================] - 12s 237ms/step - loss: 0.0012 - iou: 0.0469 - iou_thresholded: 0.0483 - val_loss: 9.7649e-04 - val_iou: 0.1059 - val_iou_thresholded: 0.1684
# Epoch 45/200
# 50/50 [==============================] - 12s 237ms/step - loss: 0.0010 - iou: 0.0891 - iou_thresholded: 0.1102 - val_loss: 9.7153e-04 - val_iou: 0.1175 - val_iou_thresholded: 0.1546
# Epoch 50/200
# 50/50 [==============================] - 12s 235ms/step - loss: 0.0010 - iou: 0.0863 - iou_thresholded: 0.0895 - val_loss: 0.0013 - val_iou: 0.0938 - val_iou_thresholded: 0.2167
# Epoch 51/200
# 50/50 [==============================] - 12s 235ms/step - loss: 0.0010 - iou: 0.0764 - iou_thresholded: 0.0819 - val_loss: 0.0011 - val_iou: 0.0790 - val_iou_thresholded: 0.0842
# Epoch 52/200
# 50/50 [==============================] - 12s 238ms/step - loss: 9.6745e-04 - iou: 0.0696 - iou_thresholded: 0.0719 - val_loss: 9.2921e-04 - val_iou: 0.1294 - val_iou_thresholded: 0.1551
# Epoch 53/200
# 50/50 [==============================] - 12s 235ms/step - loss: 9.1150e-04 - iou: 0.0921 - iou_thresholded: 0.1142 - val_loss: 9.9287e-04 - val_iou: 0.1266 - val_iou_thresholded: 0.1111
# Epoch 54/200
# 50/50 [==============================] - 12s 236ms/step - loss: 0.0011 - iou: 0.0626 - iou_thresholded: 0.0718 - val_loss: 9.1008e-04 - val_iou: 0.1183 - val_iou_thresholded: 0.1853
# Epoch 55/200
# 50/50 [==============================] - 12s 242ms/step - loss: 9.7426e-04 - iou: 0.0923 - iou_thresholded: 0.1153 - val_loss: 0.0011 - val_iou: 0.0829 - val_iou_thresholded: 0.0801
# Epoch 56/200
# 50/50 [==============================] - 12s 234ms/step - loss: 0.0010 - iou: 0.0698 - iou_thresholded: 0.0758 - val_loss: 9.4833e-04 - val_iou: 0.1325 - val_iou_thresholded: 0.1124
# Epoch 57/200
# 50/50 [==============================] - 12s 235ms/step - loss: 9.8941e-04 - iou: 0.0890 - iou_thresholded: 0.1115 - val_loss: 9.5553e-04 - val_iou: 0.1271 - val_iou_thresholded: 0.1302
# Epoch 58/200
# 50/50 [==============================] - 12s 237ms/step - loss: 9.6534e-04 - iou: 0.0919 - iou_thresholded: 0.1220 - val_loss: 9.4878e-04 - val_iou: 0.1207 - val_iou_thresholded: 0.1338
# Epoch 59/200
# 50/50 [==============================] - 12s 234ms/step - loss: 0.0010 - iou: 0.0704 - iou_thresholded: 0.0762 - val_loss: 0.0011 - val_iou: 0.0828 - val_iou_thresholded: 0.1437
# Epoch 60/200
# 50/50 [==============================] - 12s 236ms/step - loss: 0.0013 - iou: 0.0468 - iou_thresholded: 0.0559 - val_loss: 0.0011 - val_iou: 0.0740 - val_iou_thresholded: 0.0628
# Epoch 61/200
# 50/50 [==============================] - 12s 235ms/step - loss: 0.0012 - iou: 0.0604 - iou_thresholded: 0.0615 - val_loss: 9.5980e-04 - val_iou: 0.1134 - val_iou_thresholded: 0.1977
# Epoch 62/200
# 50/50 [==============================] - 12s 239ms/step - loss: 0.0011 - iou: 0.0658 - iou_thresholded: 0.0926 - val_loss: 0.0011 - val_iou: 0.0912 - val_iou_thresholded: 0.0755
# Epoch 63/200
# 50/50 [==============================] - 12s 234ms/step - loss: 9.1515e-04 - iou: 0.0977 - iou_thresholded: 0.1245 - val_loss: 9.2157e-04 - val_iou: 0.1348 - val_iou_thresholded: 0.2279
# Epoch 64/200
# 50/50 [==============================] - 12s 235ms/step - loss: 9.3915e-04 - iou: 0.0796 - iou_thresholded: 0.0969 - val_loss: 9.3310e-04 - val_iou: 0.1326 - val_iou_thresholded: 0.2320
# Epoch 65/200
# 50/50 [==============================] - 12s 240ms/step - loss: 0.0011 - iou: 0.0938 - iou_thresholded: 0.1210 - val_loss: 8.8237e-04 - val_iou: 0.1178 - val_iou_thresholded: 0.1251
# Epoch 66/200
# 50/50 [==============================] - 12s 236ms/step - loss: 9.4083e-04 - iou: 0.0906 - iou_thresholded: 0.1080 - val_loss: 8.8506e-04 - val_iou: 0.1540 - val_iou_thresholded: 0.2519
# Epoch 67/200
# 50/50 [==============================] - 12s 237ms/step - loss: 0.0011 - iou: 0.0960 - iou_thresholded: 0.1377 - val_loss: 9.3482e-04 - val_iou: 0.1008 - val_iou_thresholded: 0.1211
# Epoch 68/200
# 50/50 [==============================] - 12s 240ms/step - loss: 8.7528e-04 - iou: 0.0755 - iou_thresholded: 0.0894 - val_loss: 9.2007e-04 - val_iou: 0.1052 - val_iou_thresholded: 0.0937
# Epoch 69/200
# 50/50 [==============================] - 12s 234ms/step - loss: 9.5077e-04 - iou: 0.0956 - iou_thresholded: 0.1269 - val_loss: 0.0011 - val_iou: 0.0996 - val_iou_thresholded: 0.1693
# Epoch 70/200
# 50/50 [==============================] - 12s 236ms/step - loss: 0.0012 - iou: 0.0450 - iou_thresholded: 0.0425 - val_loss: 0.0021 - val_iou: 0.0025 - val_iou_thresholded: 0.0019
# Epoch 71/200
# 50/50 [==============================] - 12s 236ms/step - loss: 0.0016 - iou: 0.0533 - iou_thresholded: 0.0554 - val_loss: 0.0013 - val_iou: 0.0523 - val_iou_thresholded: 0.0067
# Epoch 72/200
# 50/50 [==============================] - 12s 240ms/step - loss: 0.0010 - iou: 0.0719 - iou_thresholded: 0.0948 - val_loss: 0.0012 - val_iou: 0.0427 - val_iou_thresholded: 0.0052
# Epoch 73/200
# 50/50 [==============================] - 12s 235ms/step - loss: 0.0013 - iou: 0.0760 - iou_thresholded: 0.0902 - val_loss: 9.4590e-04 - val_iou: 0.1131 - val_iou_thresholded: 0.1533
# Epoch 74/200
# 50/50 [==============================] - 12s 235ms/step - loss: 7.3116e-04 - iou: 0.0910 - iou_thresholded: 0.0960 - val_loss: 8.9322e-04 - val_iou: 0.1438 - val_iou_thresholded: 0.1848
# Epoch 75/200
# 50/50 [==============================] - 12s 238ms/step - loss: 8.6051e-04 - iou: 0.0898 - iou_thresholded: 0.1070 - val_loss: 9.4876e-04 - val_iou: 0.1251 - val_iou_thresholded: 0.2461
# Epoch 76/200
# 50/50 [==============================] - 12s 238ms/step - loss: 9.2302e-04 - iou: 0.0867 - iou_thresholded: 0.1183 - val_loss: 0.0012 - val_iou: 0.0858 - val_iou_thresholded: 0.1657
# Epoch 77/200
# 50/50 [==============================] - 12s 237ms/step - loss: 0.0012 - iou: 0.0847 - iou_thresholded: 0.1018 - val_loss: 9.2698e-04 - val_iou: 0.1538 - val_iou_thresholded: 0.2650
# Epoch 78/200
# 50/50 [==============================] - 12s 238ms/step - loss: 0.0012 - iou: 0.0765 - iou_thresholded: 0.0902 - val_loss: 9.3434e-04 - val_iou: 0.1304 - val_iou_thresholded: 0.1907
# Epoch 79/200
# 50/50 [==============================] - 12s 236ms/step - loss: 9.0098e-04 - iou: 0.0898 - iou_thresholded: 0.1180 - val_loss: 9.5601e-04 - val_iou: 0.1135 - val_iou_thresholded: 0.0999
# Epoch 80/200
# 50/50 [==============================] - 12s 236ms/step - loss: 0.0013 - iou: 0.0673 - iou_thresholded: 0.0829 - val_loss: 0.0011 - val_iou: 0.1197 - val_iou_thresholded: 0.1348
# Epoch 81/200
# 50/50 [==============================] - 12s 239ms/step - loss: 9.4733e-04 - iou: 0.0997 - iou_thresholded: 0.1309 - val_loss: 0.0011 - val_iou: 0.1051 - val_iou_thresholded: 0.0688
# Epoch 82/200
# 50/50 [==============================] - 12s 236ms/step - loss: 0.0011 - iou: 0.0744 - iou_thresholded: 0.0774 - val_loss: 9.0999e-04 - val_iou: 0.1298 - val_iou_thresholded: 0.1747
# Epoch 83/200
# 50/50 [==============================] - 12s 236ms/step - loss: 8.0582e-04 - iou: 0.0820 - iou_thresholded: 0.1098 - val_loss: 0.0010 - val_iou: 0.0709 - val_iou_thresholded: 0.0246
# Epoch 84/200
# 50/50 [==============================] - 12s 234ms/step - loss: 8.6634e-04 - iou: 0.1092 - iou_thresholded: 0.1500 - val_loss: 9.1763e-04 - val_iou: 0.1108 - val_iou_thresholded: 0.1146
# Epoch 85/200
# 50/50 [==============================] - 12s 239ms/step - loss: 0.0010 - iou: 0.0824 - iou_thresholded: 0.1117 - val_loss: 9.7045e-04 - val_iou: 0.0922 - val_iou_thresholded: 0.0823
# Epoch 86/200
# 50/50 [==============================] - 12s 235ms/step - loss: 9.3805e-04 - iou: 0.0906 - iou_thresholded: 0.1161 - val_loss: 9.4605e-04 - val_iou: 0.1517 - val_iou_thresholded: 0.2553
# Epoch 87/200
# 50/50 [==============================] - 12s 238ms/step - loss: 0.0011 - iou: 0.0851 - iou_thresholded: 0.1038 - val_loss: 8.8553e-04 - val_iou: 0.1369 - val_iou_thresholded: 0.2288
# Epoch 88/200
# 50/50 [==============================] - 12s 236ms/step - loss: 8.6423e-04 - iou: 0.1071 - iou_thresholded: 0.1536 - val_loss: 0.0012 - val_iou: 0.0558 - val_iou_thresholded: 0.0073
# Epoch 89/200
# 50/50 [==============================] - 12s 239ms/step - loss: 9.6136e-04 - iou: 0.0732 - iou_thresholded: 0.1030 - val_loss: 8.8253e-04 - val_iou: 0.1161 - val_iou_thresholded: 0.1345
# Epoch 90/200
# 50/50 [==============================] - 12s 234ms/step - loss: 8.5871e-04 - iou: 0.1148 - iou_thresholded: 0.1416 - val_loss: 9.9966e-04 - val_iou: 0.1064 - val_iou_thresholded: 0.0710
# Epoch 91/200
# 50/50 [==============================] - 12s 236ms/step - loss: 0.0013 - iou: 0.0595 - iou_thresholded: 0.0582 - val_loss: 0.0011 - val_iou: 0.0583 - val_iou_thresholded: 0.0045
# Epoch 92/200
# 50/50 [==============================] - 12s 241ms/step - loss: 8.9180e-04 - iou: 0.0896 - iou_thresholded: 0.1153 - val_loss: 8.9799e-04 - val_iou: 0.1409 - val_iou_thresholded: 0.2140
# Epoch 93/200
# 50/50 [==============================] - 12s 235ms/step - loss: 9.5001e-04 - iou: 0.1146 - iou_thresholded: 0.1382 - val_loss: 0.0012 - val_iou: 0.0668 - val_iou_thresholded: 0.0172
# Epoch 94/200
# 50/50 [==============================] - 12s 234ms/step - loss: 0.0011 - iou: 0.0765 - iou_thresholded: 0.0822 - val_loss: 0.0010 - val_iou: 0.0996 - val_iou_thresholded: 0.1291
# Epoch 95/200
# 50/50 [==============================] - 12s 235ms/step - loss: 8.6635e-04 - iou: 0.0785 - iou_thresholded: 0.0860 - val_loss: 9.2655e-04 - val_iou: 0.0973 - val_iou_thresholded: 0.0878
# Epoch 96/200
# 50/50 [==============================] - 12s 239ms/step - loss: 9.1040e-04 - iou: 0.0729 - iou_thresholded: 0.0848 - val_loss: 9.0107e-04 - val_iou: 0.1339 - val_iou_thresholded: 0.1518
# Epoch 97/200
# 50/50 [==============================] - 12s 234ms/step - loss: 9.4232e-04 - iou: 0.1110 - iou_thresholded: 0.1366 - val_loss: 8.6210e-04 - val_iou: 0.1538 - val_iou_thresholded: 0.1954
# Epoch 98/200
# 50/50 [==============================] - 12s 238ms/step - loss: 9.3349e-04 - iou: 0.1025 - iou_thresholded: 0.1381 - val_loss: 9.4352e-04 - val_iou: 0.1311 - val_iou_thresholded: 0.2538
# Epoch 99/200
# 50/50 [==============================] - 12s 240ms/step - loss: 0.0010 - iou: 0.1003 - iou_thresholded: 0.1292 - val_loss: 8.8105e-04 - val_iou: 0.1603 - val_iou_thresholded: 0.3055
# Epoch 100/200
# 50/50 [==============================] - 12s 236ms/step - loss: 0.0011 - iou: 0.0631 - iou_thresholded: 0.0755 - val_loss: 9.2339e-04 - val_iou: 0.1221 - val_iou_thresholded: 0.1779
# Epoch 101/200
# 50/50 [==============================] - 12s 234ms/step - loss: 9.0092e-04 - iou: 0.0926 - iou_thresholded: 0.1110 - val_loss: 8.2527e-04 - val_iou: 0.1675 - val_iou_thresholded: 0.2583
# Epoch 102/200
# 50/50 [==============================] - 12s 235ms/step - loss: 9.1221e-04 - iou: 0.0869 - iou_thresholded: 0.1034 - val_loss: 9.3888e-04 - val_iou: 0.1049 - val_iou_thresholded: 0.1588
# Epoch 103/200
# 50/50 [==============================] - 12s 240ms/step - loss: 9.8181e-04 - iou: 0.1187 - iou_thresholded: 0.1611 - val_loss: 8.7764e-04 - val_iou: 0.1693 - val_iou_thresholded: 0.2965
# Epoch 104/200
# 50/50 [==============================] - 12s 237ms/step - loss: 0.0011 - iou: 0.0791 - iou_thresholded: 0.0890 - val_loss: 0.0011 - val_iou: 0.1236 - val_iou_thresholded: 0.2713
# Epoch 105/200
# 50/50 [==============================] - 12s 234ms/step - loss: 0.0011 - iou: 0.0864 - iou_thresholded: 0.1015 - val_loss: 0.0011 - val_iou: 0.1228 - val_iou_thresholded: 0.1107
# Epoch 106/200
# 50/50 [==============================] - 12s 239ms/step - loss: 0.0011 - iou: 0.0707 - iou_thresholded: 0.0876 - val_loss: 0.0011 - val_iou: 0.1100 - val_iou_thresholded: 0.1885
# Epoch 107/200
# 50/50 [==============================] - 12s 235ms/step - loss: 0.0010 - iou: 0.0686 - iou_thresholded: 0.0698 - val_loss: 8.9456e-04 - val_iou: 0.1436 - val_iou_thresholded: 0.1980
# Epoch 108/200
# 50/50 [==============================] - 12s 235ms/step - loss: 8.6739e-04 - iou: 0.0776 - iou_thresholded: 0.0881 - val_loss: 9.1676e-04 - val_iou: 0.0917 - val_iou_thresholded: 0.0817
# Epoch 109/200
# 50/50 [==============================] - 12s 240ms/step - loss: 9.8977e-04 - iou: 0.0734 - iou_thresholded: 0.0799 - val_loss: 0.0010 - val_iou: 0.0570 - val_iou_thresholded: 0.0312
# Epoch 110/200
# 50/50 [==============================] - 12s 235ms/step - loss: 0.0011 - iou: 0.0899 - iou_thresholded: 0.0940 - val_loss: 9.2735e-04 - val_iou: 0.1432 - val_iou_thresholded: 0.1993
# Epoch 111/200
# 50/50 [==============================] - 12s 233ms/step - loss: 9.5586e-04 - iou: 0.0902 - iou_thresholded: 0.1140 - val_loss: 9.8976e-04 - val_iou: 0.1089 - val_iou_thresholded: 0.2110
# Epoch 112/200
# 50/50 [==============================] - 12s 239ms/step - loss: 7.7220e-04 - iou: 0.1006 - iou_thresholded: 0.1125 - val_loss: 8.4562e-04 - val_iou: 0.1301 - val_iou_thresholded: 0.1786
# Epoch 113/200
# 50/50 [==============================] - 12s 235ms/step - loss: 0.0010 - iou: 0.1089 - iou_thresholded: 0.1258 - val_loss: 8.7700e-04 - val_iou: 0.1234 - val_iou_thresholded: 0.1646
# Epoch 114/200
# 50/50 [==============================] - 12s 236ms/step - loss: 0.0011 - iou: 0.0732 - iou_thresholded: 0.0903 - val_loss: 9.5722e-04 - val_iou: 0.1166 - val_iou_thresholded: 0.1429
# Epoch 115/200
# 50/50 [==============================] - 12s 237ms/step - loss: 9.8050e-04 - iou: 0.0866 - iou_thresholded: 0.0944 - val_loss: 9.3929e-04 - val_iou: 0.1159 - val_iou_thresholded: 0.1013
# Epoch 116/200
# 50/50 [==============================] - 12s 236ms/step - loss: 8.7620e-04 - iou: 0.1077 - iou_thresholded: 0.1443 - val_loss: 9.9886e-04 - val_iou: 0.1468 - val_iou_thresholded: 0.1739
# Epoch 117/200
# 50/50 [==============================] - 12s 233ms/step - loss: 8.0007e-04 - iou: 0.1035 - iou_thresholded: 0.1289 - val_loss: 9.5685e-04 - val_iou: 0.1068 - val_iou_thresholded: 0.1123
# Epoch 118/200
# 50/50 [==============================] - 12s 236ms/step - loss: 0.0011 - iou: 0.1033 - iou_thresholded: 0.1302 - val_loss: 9.0484e-04 - val_iou: 0.1593 - val_iou_thresholded: 0.1648
# Epoch 119/200
# 50/50 [==============================] - 12s 240ms/step - loss: 0.0010 - iou: 0.0994 - iou_thresholded: 0.1215 - val_loss: 9.8069e-04 - val_iou: 0.1272 - val_iou_thresholded: 0.2298
# Epoch 120/200
# 50/50 [==============================] - 12s 235ms/step - loss: 0.0011 - iou: 0.0732 - iou_thresholded: 0.0788 - val_loss: 0.0011 - val_iou: 0.1118 - val_iou_thresholded: 0.2162
# Epoch 121/200
# 50/50 [==============================] - 12s 237ms/step - loss: 9.3195e-04 - iou: 0.1025 - iou_thresholded: 0.1443 - val_loss: 0.0015 - val_iou: 0.0870 - val_iou_thresholded: 0.2327
# Epoch 122/200
# 50/50 [==============================] - 12s 240ms/step - loss: 0.0010 - iou: 0.0660 - iou_thresholded: 0.0720 - val_loss: 8.9734e-04 - val_iou: 0.1074 - val_iou_thresholded: 0.1045
# Epoch 123/200
# 50/50 [==============================] - 12s 234ms/step - loss: 9.5848e-04 - iou: 0.0716 - iou_thresholded: 0.0862 - val_loss: 9.7119e-04 - val_iou: 0.1054 - val_iou_thresholded: 0.0814
# Epoch 124/200
# 50/50 [==============================] - 12s 234ms/step - loss: 8.9227e-04 - iou: 0.1081 - iou_thresholded: 0.1369 - val_loss: 9.5339e-04 - val_iou: 0.1418 - val_iou_thresholded: 0.1627
# Epoch 125/200
# 50/50 [==============================] - 12s 239ms/step - loss: 0.0010 - iou: 0.1076 - iou_thresholded: 0.1386 - val_loss: 8.7742e-04 - val_iou: 0.1278 - val_iou_thresholded: 0.1783
# Epoch 126/200
# 50/50 [==============================] - 12s 236ms/step - loss: 7.3873e-04 - iou: 0.1306 - iou_thresholded: 0.1878 - val_loss: 8.4977e-04 - val_iou: 0.1170 - val_iou_thresholded: 0.1382
# Epoch 127/200
# 50/50 [==============================] - 12s 238ms/step - loss: 0.0011 - iou: 0.0777 - iou_thresholded: 0.1006 - val_loss: 0.0010 - val_iou: 0.0946 - val_iou_thresholded: 0.0565
# Epoch 128/200
# 50/50 [==============================] - 12s 236ms/step - loss: 0.0011 - iou: 0.0895 - iou_thresholded: 0.1075 - val_loss: 9.3209e-04 - val_iou: 0.1424 - val_iou_thresholded: 0.1639
# Epoch 129/200
# 50/50 [==============================] - 12s 238ms/step - loss: 0.0010 - iou: 0.1191 - iou_thresholded: 0.1514 - val_loss: 0.0017 - val_iou: 0.0752 - val_iou_thresholded: 0.2548
# Epoch 130/200
# 50/50 [==============================] - 12s 236ms/step - loss: 9.8473e-04 - iou: 0.1159 - iou_thresholded: 0.1650 - val_loss: 9.1927e-04 - val_iou: 0.1450 - val_iou_thresholded: 0.2559
# Epoch 131/200
# 50/50 [==============================] - 12s 236ms/step - loss: 9.0780e-04 - iou: 0.0708 - iou_thresholded: 0.0861 - val_loss: 9.7107e-04 - val_iou: 0.1132 - val_iou_thresholded: 0.1340
# Epoch 132/200
# 50/50 [==============================] - 12s 242ms/step - loss: 9.7277e-04 - iou: 0.0792 - iou_thresholded: 0.0855 - val_loss: 8.5961e-04 - val_iou: 0.1368 - val_iou_thresholded: 0.2181
# Epoch 133/200
# 50/50 [==============================] - 12s 234ms/step - loss: 9.1304e-04 - iou: 0.0916 - iou_thresholded: 0.1187 - val_loss: 9.8626e-04 - val_iou: 0.1205 - val_iou_thresholded: 0.2648
# Epoch 134/200
# 50/50 [==============================] - 12s 234ms/step - loss: 0.0011 - iou: 0.1001 - iou_thresholded: 0.1330 - val_loss: 9.3619e-04 - val_iou: 0.1252 - val_iou_thresholded: 0.1831
# Epoch 135/200
# 50/50 [==============================] - 12s 239ms/step - loss: 7.8519e-04 - iou: 0.1111 - iou_thresholded: 0.1440 - val_loss: 8.4286e-04 - val_iou: 0.1258 - val_iou_thresholded: 0.1782
# Epoch 136/200
# 50/50 [==============================] - 12s 235ms/step - loss: 9.1380e-04 - iou: 0.1144 - iou_thresholded: 0.1423 - val_loss: 8.9664e-04 - val_iou: 0.1566 - val_iou_thresholded: 0.3120
# Epoch 137/200
# 50/50 [==============================] - 12s 236ms/step - loss: 9.6443e-04 - iou: 0.0907 - iou_thresholded: 0.1134 - val_loss: 9.6895e-04 - val_iou: 0.1576 - val_iou_thresholded: 0.2598
# Epoch 138/200
# 50/50 [==============================] - 12s 237ms/step - loss: 8.4761e-04 - iou: 0.1218 - iou_thresholded: 0.1497 - val_loss: 8.1739e-04 - val_iou: 0.1714 - val_iou_thresholded: 0.2812
# Epoch 139/200
# 50/50 [==============================] - 12s 239ms/step - loss: 0.0011 - iou: 0.1032 - iou_thresholded: 0.1379 - val_loss: 9.2135e-04 - val_iou: 0.1495 - val_iou_thresholded: 0.1677
# Epoch 140/200
# 50/50 [==============================] - 12s 234ms/step - loss: 9.6524e-04 - iou: 0.0812 - iou_thresholded: 0.0907 - val_loss: 8.9349e-04 - val_iou: 0.1476 - val_iou_thresholded: 0.1772
# Epoch 141/200
# 50/50 [==============================] - 12s 235ms/step - loss: 9.0117e-04 - iou: 0.1170 - iou_thresholded: 0.1588 - val_loss: 8.2213e-04 - val_iou: 0.2025 - val_iou_thresholded: 0.2965
# Epoch 142/200
# 50/50 [==============================] - 12s 240ms/step - loss: 9.1336e-04 - iou: 0.1100 - iou_thresholded: 0.1450 - val_loss: 8.6663e-04 - val_iou: 0.1373 - val_iou_thresholded: 0.1731
# Epoch 143/200
# 50/50 [==============================] - 12s 234ms/step - loss: 8.4626e-04 - iou: 0.1213 - iou_thresholded: 0.1525 - val_loss: 7.9368e-04 - val_iou: 0.1717 - val_iou_thresholded: 0.2691
# Epoch 144/200
# 50/50 [==============================] - 12s 237ms/step - loss: 7.1699e-04 - iou: 0.1372 - iou_thresholded: 0.1775 - val_loss: 8.5548e-04 - val_iou: 0.1352 - val_iou_thresholded: 0.1787
# Epoch 145/200
# 50/50 [==============================] - 12s 238ms/step - loss: 0.0011 - iou: 0.1014 - iou_thresholded: 0.1266 - val_loss: 0.0011 - val_iou: 0.0800 - val_iou_thresholded: 0.0997
# Epoch 146/200
# 50/50 [==============================] - 12s 235ms/step - loss: 8.0473e-04 - iou: 0.1066 - iou_thresholded: 0.1431 - val_loss: 8.3492e-04 - val_iou: 0.1368 - val_iou_thresholded: 0.2051
# Epoch 147/200
# 50/50 [==============================] - 12s 234ms/step - loss: 9.8974e-04 - iou: 0.0932 - iou_thresholded: 0.1221 - val_loss: 0.0010 - val_iou: 0.1004 - val_iou_thresholded: 0.1698
# Epoch 148/200
# 50/50 [==============================] - 12s 239ms/step - loss: 0.0010 - iou: 0.0867 - iou_thresholded: 0.1162 - val_loss: 8.9135e-04 - val_iou: 0.1394 - val_iou_thresholded: 0.2109
# Epoch 149/200
# 50/50 [==============================] - 12s 237ms/step - loss: 9.5370e-04 - iou: 0.0945 - iou_thresholded: 0.1136 - val_loss: 9.0675e-04 - val_iou: 0.1076 - val_iou_thresholded: 0.1767
# Epoch 150/200
# 50/50 [==============================] - 12s 235ms/step - loss: 8.7050e-04 - iou: 0.1126 - iou_thresholded: 0.1598 - val_loss: 9.9768e-04 - val_iou: 0.1317 - val_iou_thresholded: 0.1552
# Epoch 151/200
# 50/50 [==============================] - 12s 236ms/step - loss: 8.7588e-04 - iou: 0.1142 - iou_thresholded: 0.1584 - val_loss: 8.6056e-04 - val_iou: 0.1484 - val_iou_thresholded: 0.2166
# Epoch 152/200
# 50/50 [==============================] - 12s 239ms/step - loss: 0.0011 - iou: 0.1223 - iou_thresholded: 0.1766 - val_loss: 9.1706e-04 - val_iou: 0.1317 - val_iou_thresholded: 0.2340
# Epoch 153/200
# 50/50 [==============================] - 12s 235ms/step - loss: 9.8683e-04 - iou: 0.1034 - iou_thresholded: 0.1436 - val_loss: 8.6044e-04 - val_iou: 0.1375 - val_iou_thresholded: 0.1943
# Epoch 154/200
# 50/50 [==============================] - 13s 259ms/step - loss: 8.5465e-04 - iou: 0.1432 - iou_thresholded: 0.2064 - val_loss: 7.8813e-04 - val_iou: 0.1855 - val_iou_thresholded: 0.2954
# Epoch 155/200
# 50/50 [==============================] - 12s 239ms/step - loss: 7.2979e-04 - iou: 0.1266 - iou_thresholded: 0.1684 - val_loss: 8.0011e-04 - val_iou: 0.1521 - val_iou_thresholded: 0.2626
# Epoch 156/200
# 50/50 [==============================] - 12s 235ms/step - loss: 8.6335e-04 - iou: 0.1400 - iou_thresholded: 0.1997 - val_loss: 8.0651e-04 - val_iou: 0.1850 - val_iou_thresholded: 0.2530
# Epoch 157/200
# 50/50 [==============================] - 12s 234ms/step - loss: 9.0058e-04 - iou: 0.0721 - iou_thresholded: 0.0848 - val_loss: 0.0010 - val_iou: 0.1005 - val_iou_thresholded: 0.0944
# Epoch 158/200
# 50/50 [==============================] - 12s 236ms/step - loss: 9.0940e-04 - iou: 0.1218 - iou_thresholded: 0.1606 - val_loss: 9.8011e-04 - val_iou: 0.1237 - val_iou_thresholded: 0.1459
# Epoch 159/200
# 50/50 [==============================] - 12s 241ms/step - loss: 8.8885e-04 - iou: 0.1252 - iou_thresholded: 0.1487 - val_loss: 9.6754e-04 - val_iou: 0.1542 - val_iou_thresholded: 0.1319
# Epoch 160/200
# 50/50 [==============================] - 12s 237ms/step - loss: 8.3841e-04 - iou: 0.0986 - iou_thresholded: 0.1307 - val_loss: 9.2645e-04 - val_iou: 0.1180 - val_iou_thresholded: 0.0862
# Epoch 161/200
# 50/50 [==============================] - 12s 234ms/step - loss: 9.3438e-04 - iou: 0.1439 - iou_thresholded: 0.2003 - val_loss: 8.6322e-04 - val_iou: 0.1532 - val_iou_thresholded: 0.2383
# Epoch 162/200
# 50/50 [==============================] - 12s 235ms/step - loss: 9.6673e-04 - iou: 0.1177 - iou_thresholded: 0.1695 - val_loss: 8.0993e-04 - val_iou: 0.1525 - val_iou_thresholded: 0.2170
# Epoch 163/200
# 50/50 [==============================] - 12s 237ms/step - loss: 8.9836e-04 - iou: 0.1258 - iou_thresholded: 0.1574 - val_loss: 8.3603e-04 - val_iou: 0.1500 - val_iou_thresholded: 0.1669
# Epoch 164/200
# 50/50 [==============================] - 12s 234ms/step - loss: 8.2142e-04 - iou: 0.1189 - iou_thresholded: 0.1684 - val_loss: 8.2890e-04 - val_iou: 0.1541 - val_iou_thresholded: 0.2062
# Epoch 165/200
# 50/50 [==============================] - 12s 239ms/step - loss: 8.9509e-04 - iou: 0.0938 - iou_thresholded: 0.1300 - val_loss: 8.9084e-04 - val_iou: 0.1455 - val_iou_thresholded: 0.1869
# Epoch 166/200
# 50/50 [==============================] - 12s 240ms/step - loss: 9.0715e-04 - iou: 0.1298 - iou_thresholded: 0.1719 - val_loss: 8.3257e-04 - val_iou: 0.1502 - val_iou_thresholded: 0.2194
# Epoch 167/200
# 50/50 [==============================] - 12s 236ms/step - loss: 8.6320e-04 - iou: 0.1222 - iou_thresholded: 0.1656 - val_loss: 9.2315e-04 - val_iou: 0.1160 - val_iou_thresholded: 0.1405
# Epoch 168/200
# 50/50 [==============================] - 12s 234ms/step - loss: 9.1230e-04 - iou: 0.0993 - iou_thresholded: 0.1363 - val_loss: 8.3548e-04 - val_iou: 0.1829 - val_iou_thresholded: 0.3299
# Epoch 169/200
# 50/50 [==============================] - 12s 236ms/step - loss: 9.6329e-04 - iou: 0.1053 - iou_thresholded: 0.1324 - val_loss: 9.8531e-04 - val_iou: 0.1091 - val_iou_thresholded: 0.1880
# Epoch 170/200
# 50/50 [==============================] - 12s 242ms/step - loss: 0.0011 - iou: 0.1052 - iou_thresholded: 0.1372 - val_loss: 9.9454e-04 - val_iou: 0.1377 - val_iou_thresholded: 0.1440
# Epoch 171/200
# 50/50 [==============================] - 12s 236ms/step - loss: 9.3058e-04 - iou: 0.1033 - iou_thresholded: 0.1297 - val_loss: 9.5467e-04 - val_iou: 0.1095 - val_iou_thresholded: 0.0782
# Epoch 172/200
# 50/50 [==============================] - 12s 234ms/step - loss: 0.0010 - iou: 0.0963 - iou_thresholded: 0.1276 - val_loss: 0.0012 - val_iou: 0.0364 - val_iou_thresholded: 0.0024
# Epoch 173/200
# 50/50 [==============================] - 12s 239ms/step - loss: 9.9674e-04 - iou: 0.0579 - iou_thresholded: 0.0600 - val_loss: 9.3353e-04 - val_iou: 0.1292 - val_iou_thresholded: 0.2641
# Epoch 174/200
# 50/50 [==============================] - 12s 235ms/step - loss: 0.0012 - iou: 0.0822 - iou_thresholded: 0.1042 - val_loss: 0.0011 - val_iou: 0.0957 - val_iou_thresholded: 0.0539
# Epoch 175/200
# 50/50 [==============================] - 12s 236ms/step - loss: 7.8773e-04 - iou: 0.0719 - iou_thresholded: 0.0823 - val_loss: 0.0011 - val_iou: 0.0670 - val_iou_thresholded: 0.0181
# Epoch 176/200
# 50/50 [==============================] - 12s 241ms/step - loss: 0.0010 - iou: 0.1378 - iou_thresholded: 0.1868 - val_loss: 9.2031e-04 - val_iou: 0.1481 - val_iou_thresholded: 0.3065
# Epoch 177/200
# 50/50 [==============================] - 12s 235ms/step - loss: 8.8044e-04 - iou: 0.1077 - iou_thresholded: 0.1352 - val_loss: 9.7980e-04 - val_iou: 0.1195 - val_iou_thresholded: 0.0845
# Epoch 178/200
# 50/50 [==============================] - 12s 235ms/step - loss: 9.6166e-04 - iou: 0.1162 - iou_thresholded: 0.1287 - val_loss: 0.0010 - val_iou: 0.0991 - val_iou_thresholded: 0.0342
# Epoch 179/200
# 50/50 [==============================] - 12s 237ms/step - loss: 0.0011 - iou: 0.0868 - iou_thresholded: 0.0999 - val_loss: 0.0010 - val_iou: 0.0770 - val_iou_thresholded: 0.0518
# Epoch 180/200
# 50/50 [==============================] - 12s 239ms/step - loss: 9.8805e-04 - iou: 0.1174 - iou_thresholded: 0.1615 - val_loss: 8.5591e-04 - val_iou: 0.1422 - val_iou_thresholded: 0.2671
# Epoch 181/200
# 50/50 [==============================] - 12s 237ms/step - loss: 9.6218e-04 - iou: 0.0953 - iou_thresholded: 0.1236 - val_loss: 8.9930e-04 - val_iou: 0.1487 - val_iou_thresholded: 0.2753
# Epoch 182/200
# 50/50 [==============================] - 12s 237ms/step - loss: 7.9967e-04 - iou: 0.1124 - iou_thresholded: 0.1646 - val_loss: 8.7765e-04 - val_iou: 0.1309 - val_iou_thresholded: 0.1291
# Epoch 183/200
# 50/50 [==============================] - 12s 239ms/step - loss: 8.5479e-04 - iou: 0.0993 - iou_thresholded: 0.1236 - val_loss: 8.6621e-04 - val_iou: 0.1206 - val_iou_thresholded: 0.1314
# Epoch 184/200
# 50/50 [==============================] - 12s 236ms/step - loss: 0.0011 - iou: 0.0841 - iou_thresholded: 0.0941 - val_loss: 9.0874e-04 - val_iou: 0.1137 - val_iou_thresholded: 0.1443
# Epoch 185/200
# 50/50 [==============================] - 12s 234ms/step - loss: 0.0010 - iou: 0.0953 - iou_thresholded: 0.1510 - val_loss: 8.9380e-04 - val_iou: 0.1215 - val_iou_thresholded: 0.1971
# Epoch 186/200
# 50/50 [==============================] - 12s 240ms/step - loss: 9.1606e-04 - iou: 0.1245 - iou_thresholded: 0.1610 - val_loss: 8.5065e-04 - val_iou: 0.1478 - val_iou_thresholded: 0.2461
# Epoch 187/200
# 50/50 [==============================] - 12s 237ms/step - loss: 9.0519e-04 - iou: 0.1151 - iou_thresholded: 0.1650 - val_loss: 8.7562e-04 - val_iou: 0.1784 - val_iou_thresholded: 0.2920
# Epoch 188/200
# 50/50 [==============================] - 12s 236ms/step - loss: 9.1669e-04 - iou: 0.0857 - iou_thresholded: 0.1163 - val_loss: 9.1101e-04 - val_iou: 0.1414 - val_iou_thresholded: 0.1317
# Epoch 189/200
# 50/50 [==============================] - 12s 238ms/step - loss: 8.1972e-04 - iou: 0.1245 - iou_thresholded: 0.1582 - val_loss: 7.9612e-04 - val_iou: 0.1638 - val_iou_thresholded: 0.2184
# Epoch 190/200
# 50/50 [==============================] - 12s 235ms/step - loss: 9.7754e-04 - iou: 0.1203 - iou_thresholded: 0.1720 - val_loss: 9.0175e-04 - val_iou: 0.1415 - val_iou_thresholded: 0.1930
# Epoch 191/200
# 50/50 [==============================] - 12s 234ms/step - loss: 8.0665e-04 - iou: 0.1257 - iou_thresholded: 0.1665 - val_loss: 7.7147e-04 - val_iou: 0.2036 - val_iou_thresholded: 0.3592
# Epoch 192/200
# 50/50 [==============================] - 12s 237ms/step - loss: 7.9473e-04 - iou: 0.1565 - iou_thresholded: 0.2260 - val_loss: 7.9880e-04 - val_iou: 0.2184 - val_iou_thresholded: 0.3012
# Epoch 193/200
# 50/50 [==============================] - 12s 241ms/step - loss: 9.3241e-04 - iou: 0.1022 - iou_thresholded: 0.1356 - val_loss: 8.6873e-04 - val_iou: 0.1311 - val_iou_thresholded: 0.0994
# Epoch 194/200
# 50/50 [==============================] - 12s 235ms/step - loss: 8.5104e-04 - iou: 0.1343 - iou_thresholded: 0.1876 - val_loss: 8.6517e-04 - val_iou: 0.1551 - val_iou_thresholded: 0.2511
# Epoch 195/200
# 50/50 [==============================] - 12s 235ms/step - loss: 7.1825e-04 - iou: 0.1631 - iou_thresholded: 0.2468 - val_loss: 7.5980e-04 - val_iou: 0.2303 - val_iou_thresholded: 0.3312
# Epoch 196/200
# 50/50 [==============================] - 12s 239ms/step - loss: 8.6907e-04 - iou: 0.1320 - iou_thresholded: 0.1814 - val_loss: 7.8800e-04 - val_iou: 0.1885 - val_iou_thresholded: 0.3139
# Epoch 197/200
# 50/50 [==============================] - 12s 235ms/step - loss: 8.1521e-04 - iou: 0.1373 - iou_thresholded: 0.1718 - val_loss: 8.7805e-04 - val_iou: 0.1609 - val_iou_thresholded: 0.1782
# Epoch 198/200
# 50/50 [==============================] - 12s 237ms/step - loss: 0.0011 - iou: 0.0952 - iou_thresholded: 0.1445 - val_loss: 0.0011 - val_iou: 0.1519 - val_iou_thresholded: 0.2008
# Epoch 199/200
# 50/50 [==============================] - 12s 234ms/step - loss: 8.6726e-04 - iou: 0.1056 - iou_thresholded: 0.1460 - val_loss: 0.0010 - val_iou: 0.1317 - val_iou_thresholded: 0.1128
# Epoch 200/200
# 50/50 [==============================] - 12s 239ms/step - loss: 8.9096e-04 - iou: 0.1502 - iou_thresholded: 0.2159 - val_loss: 8.1491e-04 - val_iou: 0.1590 - val_iou_thresholded: 0.2598

# %%
from keras_unet.utils import plot_segm_history

plot_segm_history(history)

# %%
y_pred = model.predict(X_test)

# %%
from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=X_test, mask_imgs=y_test, pred_imgs=y_pred, nm_img_to_plot=10)

# %%
loss, iou, iou_thresholded = model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 2s 356ms/step - loss: 7.6226e-04 - iou: 0.1732 - iou_thresholded: 0.2985
