# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import os
import keras
from keras_unet.models import custom_unet
from sklearn.model_selection import train_test_split
# Out:
# 2023-02-17 16:37:26.713437: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# /home/jiehyun.kim001/miniconda3/envs/O/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# -----------------------------------------
# keras-unet init: TF version is >= 2.0.0 - using `tf.keras` instead of `Keras`
# -----------------------------------------

# %%
DATAPATH = '/raid/mpsych/CACTAS/DATA/Nathan Arnett Calcification'
images_file = os.path.join(DATAPATH, 'images.npy')
labels_file = os.path.join(DATAPATH, 'labels.npy')

# %%
images = np.load(images_file)
labels = np.load(labels_file)

# %%
images.shape
# Out:
# (503, 512, 512)

# %%
images.ndim, labels.ndim
# Out:
# (3, 3)

# %%
# full dataset does not have the last channel
images = images.reshape(images.shape[0],images.shape[1],images.shape[2],1)
labels = labels.reshape(labels.shape[0],labels.shape[1],labels.shape[2],1)

# %%
p = np.random.permutation(len(images))

# %%
images = images[p]
labels = labels[p]

# %%
images = images.astype(np.float64)
labels = labels.astype(np.float64)

# %%
for i in range(images.shape[0]):
    
    images[i] = (images[i] - images[i].min()) / (images[i].max() - images[i].min()) # normalize individually

# %%
images.shape
# Out:
# (503, 512, 512, 1)

# %%
labels.shape
# Out:
# (503, 512, 512, 1)

# %%
from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=images, mask_imgs=labels, nm_img_to_plot=3, figsize=5)

# %%
X_train, X_val, y_train, y_val = train_test_split(images, labels, test_size=0.2, random_state=0)

# %%
from keras_unet.utils import get_augmented

train_gen = get_augmented(
    X_train, y_train, batch_size=2,
    data_gen_args = dict(
        rotation_range=5.,
        width_shift_range=0.05,
        height_shift_range=0.05,
        shear_range=40,
        zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='constant'
    ))

# %%
sample_batch = next(train_gen)
xx, yy = sample_batch
print(xx.shape, yy.shape)
from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=xx, mask_imgs=yy, nm_img_to_plot=2, figsize=6)
# Out:
# (2, 512, 512, 1) (2, 512, 512, 1)

# %%
from keras_unet_collection import models, losses
import torch

model = models.swin_unet_2d((512, 512, 1), filter_num_begin=64,
                               n_labels=1, depth=4, stack_num_down=4, stack_num_up=4,
                               patch_size=(4, 4), num_heads=[4, 8, 16, 16],
                               window_size=[4, 2, 2, 2], num_mlp=512, 
                               output_activation='Sigmoid', shift_window=True, name='swin_unet')

#Softmax
# Out:
# 2023-02-06 23:02:21.723326: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-02-06 23:02:21.855934: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:b7:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2023-02-06 23:02:21.855969: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-02-06 23:02:21.856002: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-02-06 23:02:21.856019: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-02-06 23:02:21.856930: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-02-06 23:02:21.857246: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-02-06 23:02:21.857745: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-02-06 23:02:21.858455: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-02-06 23:02:21.858487: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-02-06 23:02:21.866999: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# WARNING:tensorflow:From /home/jiehyun.kim001/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# 2023-02-06 23:02:21.867665: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-06 23:02:21.871540: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:b7:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2023-02-06 23:02:21.879759: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-02-06 23:02:21.879784: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-02-06 23:02:22.452336: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-02-06 23:02:22.452374: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-02-06 23:02:22.452380: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-02-06 23:02:22.464741: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 38425 MB memory) -> physical GPU (device: 0, name: A100-SXM4-40GB, pci bus id: 0000:b7:00.0, compute capability: 8.0)

# %%
model.summary()
# Out:
# Model: "swin_unet_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# patch_extract (patch_extract)   (None, 16384, 16)    0           input_1[0][0]
# __________________________________________________________________________________________________
# patch_embedding (patch_embeddin (None, 16384, 64)    1049664     patch_extract[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block (SwinTra (None, 16384, 64)    83460       patch_embedding[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_1 (SwinT (None, 16384, 64)    345604      swin_transformer_block[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_2 (SwinT (None, 16384, 64)    83460       swin_transformer_block_1[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_3 (SwinT (None, 16384, 64)    345604      swin_transformer_block_2[0][0]
# __________________________________________________________________________________________________
# patch_merging (patch_merging)   (None, 4096, 128)    32768       swin_transformer_block_3[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_4 (SwinT (None, 4096, 128)    198360      patch_merging[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_5 (SwinT (None, 4096, 128)    214744      swin_transformer_block_4[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_6 (SwinT (None, 4096, 128)    198360      swin_transformer_block_5[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_7 (SwinT (None, 4096, 128)    214744      swin_transformer_block_6[0][0]
# __________________________________________________________________________________________________
# patch_merging_1 (patch_merging) (None, 1024, 256)    131072      swin_transformer_block_7[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_8 (SwinT (None, 1024, 256)    527264      patch_merging_1[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_9 (SwinT (None, 1024, 256)    531360      swin_transformer_block_8[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_10 (Swin (None, 1024, 256)    527264      swin_transformer_block_9[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_11 (Swin (None, 1024, 256)    531360      swin_transformer_block_10[0][0]
# __________________________________________________________________________________________________
# patch_merging_2 (patch_merging) (None, 256, 512)     524288      swin_transformer_block_11[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_12 (Swin (None, 256, 512)     1578144     patch_merging_2[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_13 (Swin (None, 256, 512)     1579168     swin_transformer_block_12[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_14 (Swin (None, 256, 512)     1578144     swin_transformer_block_13[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_15 (Swin (None, 256, 512)     1579168     swin_transformer_block_14[0][0]
# __________________________________________________________________________________________________
# patch_expanding (patch_expandin (None, 1024, 256)    524288      swin_transformer_block_15[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_0 (Concatenate (None, 1024, 512)    0           patch_expanding[0][0]
#                                                                  swin_transformer_block_11[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_linear_proj_0  (None, 1024, 256)    131072      swin_unet_concat_0[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_16 (Swin (None, 1024, 256)    527264      swin_unet_concat_linear_proj_0[0]
# __________________________________________________________________________________________________
# swin_transformer_block_17 (Swin (None, 1024, 256)    531360      swin_transformer_block_16[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_18 (Swin (None, 1024, 256)    527264      swin_transformer_block_17[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_19 (Swin (None, 1024, 256)    531360      swin_transformer_block_18[0][0]
# __________________________________________________________________________________________________
# patch_expanding_1 (patch_expand (None, 4096, 128)    131072      swin_transformer_block_19[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_1 (Concatenate (None, 4096, 256)    0           patch_expanding_1[0][0]
#                                                                  swin_transformer_block_7[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_linear_proj_1  (None, 4096, 128)    32768       swin_unet_concat_1[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_20 (Swin (None, 4096, 128)    198432      swin_unet_concat_linear_proj_1[0]
# __________________________________________________________________________________________________
# swin_transformer_block_21 (Swin (None, 4096, 128)    214816      swin_transformer_block_20[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_22 (Swin (None, 4096, 128)    198432      swin_transformer_block_21[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_23 (Swin (None, 4096, 128)    214816      swin_transformer_block_22[0][0]
# __________________________________________________________________________________________________
# patch_expanding_2 (patch_expand (None, 16384, 64)    32768       swin_transformer_block_23[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_2 (Concatenate (None, 16384, 128)   0           patch_expanding_2[0][0]
#                                                                  swin_transformer_block_3[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_linear_proj_2  (None, 16384, 64)    8192        swin_unet_concat_2[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_24 (Swin (None, 16384, 64)    83096       swin_unet_concat_linear_proj_2[0]
# __________________________________________________________________________________________________
# swin_transformer_block_25 (Swin (None, 16384, 64)    148632      swin_transformer_block_24[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_26 (Swin (None, 16384, 64)    83096       swin_transformer_block_25[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_27 (Swin (None, 16384, 64)    148632      swin_transformer_block_26[0][0]
# __________________________________________________________________________________________________
# patch_expanding_3 (patch_expand (None, 512, 512, 16) 16384       swin_transformer_block_27[0][0]
# __________________________________________________________________________________________________
# swin_unet_output (Conv2D)       (None, 512, 512, 1)  17          patch_expanding_3[0][0]
# __________________________________________________________________________________________________
# swin_unet_output_activation (Ac (None, 512, 512, 1)  0           swin_unet_output[0][0]
# ==================================================================================================
# Total params: 16,137,761
# Trainable params: 15,397,025
# Non-trainable params: 740,736
# __________________________________________________________________________________________________

# %%
from tensorflow import keras
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01,
    decay_steps=10000,
    decay_rate=0.9)

# %%
from tensorflow.keras.callbacks import EarlyStopping

earlystopping = EarlyStopping(
    monitor="val_iou",
    min_delta=0,
    patience=30,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=True
)

# %%
from tensorflow.keras import optimizers
from keras_unet.metrics import iou, iou_thresholded, dice_coef
from keras_unet_collection import losses

# %%
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(learning_rate=0.001),
              metrics=[iou, iou_thresholded])

# %%
history = model.fit(#X_train, 
                    #y_train,
                    train_gen,
                    batch_size=16, 
                    epochs=200,
                    validation_data=(X_val, y_val),
                    callbacks = [earlystopping])
# Out:
# 2023-02-06 23:02:48.581512: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-02-06 23:02:48.601190: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245645000 Hz
# Epoch 1/200
# 2023-02-06 23:03:13.112620: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-02-06 23:03:13.901748: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-02-06 23:03:13.902097: I tensorflow/stream_executor/cuda/cuda_blas.cc:1838] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-02-06 23:03:13.943008: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-02-06 23:03:14.084908: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8500
# 2023-02-06 23:03:14.545509: W tensorflow/stream_executor/gpu/asm_compiler.cc:191] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.0
# 2023-02-06 23:03:14.545532: W tensorflow/stream_executor/gpu/asm_compiler.cc:194] Used ptxas at ptxas
# 2023-02-06 23:03:14.545585: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Unimplemented: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
#    3125/Unknown - 677s 208ms/step - loss: 0.0027 - iou: 0.0231 - iou_thresholded: 0.0289

# %%
from keras_unet.utils import plot_segm_history

plot_segm_history(history)

# %%
y_pred = model.predict(X_val)

# %%
from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=X_val, mask_imgs=y_val, pred_imgs=y_pred, nm_img_to_plot=10)

# %%
loss, iou, iou_thresholded = model.evaluate(X_val, y_val)
# Out:
# 4/4 [==============================] - 2s 335ms/step - loss: 6.7572e-04 - iou: 0.5032 - iou_thresholded: 0.5127
