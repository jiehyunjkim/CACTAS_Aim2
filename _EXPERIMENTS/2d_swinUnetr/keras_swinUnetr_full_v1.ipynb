# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import os
import keras
from keras_unet.models import custom_unet
# Out:
# 2023-01-27 21:47:48.026703: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# -----------------------------------------
# keras-unet init: TF version is >= 2.0.0 - using `tf.keras` instead of `Keras`
# -----------------------------------------

# %%
#DATAPATH = '/Users/jiehyun/Jenna/UMassBoston/Research/Nathan_Arnett_Calcification/'
DATAPATH = '/raid/mpsych/CACTAS/DATA/Nathan Arnett Calcification'
images_file = os.path.join(DATAPATH, 'images.npy')
labels_file = os.path.join(DATAPATH, 'labels.npy')

# %%
images = np.load(images_file)
labels = np.load(labels_file)

# %%
# full dataset does not have the last channel
images = images.reshape(images.shape[0],images.shape[1],images.shape[2],1)
labels = labels.reshape(labels.shape[0],labels.shape[1],labels.shape[2],1)

# %%
p = np.random.permutation(len(images))

# %%
images = images[p]
labels = labels[p]

# %%
images = images.astype(np.float64)
labels = labels.astype(np.float64)

# %%
for i in range(images.shape[0]):
    
    images[i] = (images[i] - images[i].min()) / (images[i].max() - images[i].min()) # normalize individually

# %%
images.shape
# Out:
# (503, 512, 512, 1)

# %%
labels.shape
# Out:
# (503, 512, 512, 1)

# %%
from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=images, mask_imgs=labels, nm_img_to_plot=3, figsize=5)

# %%
X_train = images[0:300]
y_train = labels[0:300]
X_val = images[300:400]
y_val = labels[300:400]
X_test = images[400:]
y_test = labels[400:]

# %%
from keras_unet_collection import models, losses
import torch

model = models.swin_unet_2d((512, 512, 1), filter_num_begin=64,
                               n_labels=1, depth=4, stack_num_down=4, stack_num_up=4,
                               patch_size=(4, 4), num_heads=[4, 8, 8, 8],
                               window_size=[4, 2, 2, 2], num_mlp=512, 
                               output_activation='Softmax', shift_window=True, name='swin_unet')
# Out:
# 2023-01-27 21:48:00.968427: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-01-27 21:48:01.137942: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:87:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2023-01-27 21:48:01.137978: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-01-27 21:48:01.138009: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-01-27 21:48:01.138025: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-01-27 21:48:01.138995: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-01-27 21:48:01.139306: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-01-27 21:48:01.139836: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-01-27 21:48:01.140576: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-01-27 21:48:01.140605: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-01-27 21:48:01.148423: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-01-27 21:48:01.149161: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-27 21:48:01.153392: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:87:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2023-01-27 21:48:01.161208: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-01-27 21:48:01.161234: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-01-27 21:48:01.999660: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-01-27 21:48:01.999706: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-01-27 21:48:01.999712: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-01-27 21:48:02.012432: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 38425 MB memory) -> physical GPU (device: 0, name: A100-SXM4-40GB, pci bus id: 0000:87:00.0, compute capability: 8.0)
# WARNING:tensorflow:From /home/jiehyun.kim001/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.

# %%
model.summary()
# Out:
# Model: "swin_unet_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# patch_extract (patch_extract)   (None, 16384, 16)    0           input_1[0][0]
# __________________________________________________________________________________________________
# patch_embedding (patch_embeddin (None, 16384, 64)    1049664     patch_extract[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block (SwinTra (None, 16384, 64)    83460       patch_embedding[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_1 (SwinT (None, 16384, 64)    345604      swin_transformer_block[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_2 (SwinT (None, 16384, 64)    83460       swin_transformer_block_1[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_3 (SwinT (None, 16384, 64)    345604      swin_transformer_block_2[0][0]
# __________________________________________________________________________________________________
# patch_merging (patch_merging)   (None, 4096, 128)    32768       swin_transformer_block_3[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_4 (SwinT (None, 4096, 128)    198360      patch_merging[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_5 (SwinT (None, 4096, 128)    214744      swin_transformer_block_4[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_6 (SwinT (None, 4096, 128)    198360      swin_transformer_block_5[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_7 (SwinT (None, 4096, 128)    214744      swin_transformer_block_6[0][0]
# __________________________________________________________________________________________________
# patch_merging_1 (patch_merging) (None, 1024, 256)    131072      swin_transformer_block_7[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_8 (SwinT (None, 1024, 256)    527192      patch_merging_1[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_9 (SwinT (None, 1024, 256)    531288      swin_transformer_block_8[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_10 (Swin (None, 1024, 256)    527192      swin_transformer_block_9[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_11 (Swin (None, 1024, 256)    531288      swin_transformer_block_10[0][0]
# __________________________________________________________________________________________________
# patch_merging_2 (patch_merging) (None, 256, 512)     524288      swin_transformer_block_11[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_12 (Swin (None, 256, 512)     1578072     patch_merging_2[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_13 (Swin (None, 256, 512)     1579096     swin_transformer_block_12[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_14 (Swin (None, 256, 512)     1578072     swin_transformer_block_13[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_15 (Swin (None, 256, 512)     1579096     swin_transformer_block_14[0][0]
# __________________________________________________________________________________________________
# patch_expanding (patch_expandin (None, 1024, 256)    524288      swin_transformer_block_15[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_0 (Concatenate (None, 1024, 512)    0           patch_expanding[0][0]
#                                                                  swin_transformer_block_11[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_linear_proj_0  (None, 1024, 256)    131072      swin_unet_concat_0[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_16 (Swin (None, 1024, 256)    527192      swin_unet_concat_linear_proj_0[0]
# __________________________________________________________________________________________________
# swin_transformer_block_17 (Swin (None, 1024, 256)    531288      swin_transformer_block_16[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_18 (Swin (None, 1024, 256)    527192      swin_transformer_block_17[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_19 (Swin (None, 1024, 256)    531288      swin_transformer_block_18[0][0]
# __________________________________________________________________________________________________
# patch_expanding_1 (patch_expand (None, 4096, 128)    131072      swin_transformer_block_19[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_1 (Concatenate (None, 4096, 256)    0           patch_expanding_1[0][0]
#                                                                  swin_transformer_block_7[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_linear_proj_1  (None, 4096, 128)    32768       swin_unet_concat_1[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_20 (Swin (None, 4096, 128)    198360      swin_unet_concat_linear_proj_1[0]
# __________________________________________________________________________________________________
# swin_transformer_block_21 (Swin (None, 4096, 128)    214744      swin_transformer_block_20[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_22 (Swin (None, 4096, 128)    198360      swin_transformer_block_21[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_23 (Swin (None, 4096, 128)    214744      swin_transformer_block_22[0][0]
# __________________________________________________________________________________________________
# patch_expanding_2 (patch_expand (None, 16384, 64)    32768       swin_transformer_block_23[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_2 (Concatenate (None, 16384, 128)   0           patch_expanding_2[0][0]
#                                                                  swin_transformer_block_3[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_linear_proj_2  (None, 16384, 64)    8192        swin_unet_concat_2[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_24 (Swin (None, 16384, 64)    83096       swin_unet_concat_linear_proj_2[0]
# __________________________________________________________________________________________________
# swin_transformer_block_25 (Swin (None, 16384, 64)    148632      swin_transformer_block_24[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_26 (Swin (None, 16384, 64)    83096       swin_transformer_block_25[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_27 (Swin (None, 16384, 64)    148632      swin_transformer_block_26[0][0]
# __________________________________________________________________________________________________
# patch_expanding_3 (patch_expand (None, 512, 512, 16) 16384       swin_transformer_block_27[0][0]
# __________________________________________________________________________________________________
# swin_unet_output (Conv2D)       (None, 512, 512, 1)  17          patch_expanding_3[0][0]
# __________________________________________________________________________________________________
# swin_unet_output_activation (So (None, 512, 512, 1)  0           swin_unet_output[0][0]
# ==================================================================================================
# Total params: 16,136,609
# Trainable params: 15,395,873
# Non-trainable params: 740,736
# __________________________________________________________________________________________________

# %%
#model = custom_unet(
#    input_shape=(512, 512, 1),
#    use_batch_norm=False,
#    num_classes=1,
#    filters=32,
#    dropout=0.5,
#    output_activation='sigmoid')

# %%
from tensorflow.keras import optimizers
from tensorflow.keras.optimizers import Adam
#import keras.optimizers
from keras_unet.metrics import iou, iou_thresholded, dice_coef
#from keras_unet.losses import jaccard_distance
from keras_unet_collection import losses

# %%
model.compile(loss='binary_crossentropy',
              #optimizer=keras.optimizers.Adam(lr=1e-3),
              optimizer = 'Adam',
              metrics=['accuracy', losses.dice_coef, iou, iou_thresholded])

# %%
#model.compile(optimizer = 'Adam',    
#              loss='binary_crossentropy', 
#              #loss = losses.focal_tversky,
#              metrics=[iou, iou_thresholded, dice_coef, 'accuracy'])

# %%
history = model.fit(X_train, 
                    y_train, 
                    batch_size=4, 
                    epochs=100,
                    validation_data=(X_val, y_val))
# Out:
# 2023-01-27 21:48:52.729994: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-01-27 21:48:52.749179: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245645000 Hz
# Epoch 1/100
# 2023-01-27 21:49:10.710119: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-01-27 21:49:11.650285: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-01-27 21:49:11.650620: I tensorflow/stream_executor/cuda/cuda_blas.cc:1838] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-01-27 21:49:11.687879: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-01-27 21:49:11.846615: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8500
# 2023-01-27 21:49:12.392093: W tensorflow/stream_executor/gpu/asm_compiler.cc:191] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.0
# 2023-01-27 21:49:12.392116: W tensorflow/stream_executor/gpu/asm_compiler.cc:194] Used ptxas at ptxas
# 2023-01-27 21:49:12.392173: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Unimplemented: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 75/75 [==============================] - 40s 265ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2720e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 2/100
# 75/75 [==============================] - 16s 212ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2720e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 3/100
# 75/75 [==============================] - 16s 216ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 4/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 5/100
# 75/75 [==============================] - 16s 214ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 6/100
# 75/75 [==============================] - 16s 213ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 7/100
# 75/75 [==============================] - 16s 212ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 8/100
# 75/75 [==============================] - 16s 215ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 9/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 10/100
# 75/75 [==============================] - 16s 215ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 11/100
# 75/75 [==============================] - 16s 210ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 12/100
# 75/75 [==============================] - 16s 212ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 13/100
# 75/75 [==============================] - 16s 217ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2722e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 14/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 15/100
# 75/75 [==============================] - 16s 216ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 16/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2720e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 17/100
# 75/75 [==============================] - 16s 212ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 18/100
# 75/75 [==============================] - 16s 215ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 19/100
# 75/75 [==============================] - 16s 212ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 20/100
# 75/75 [==============================] - 16s 216ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 21/100
# 75/75 [==============================] - 16s 212ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 22/100
# 75/75 [==============================] - 16s 212ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2720e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 23/100
# 75/75 [==============================] - 16s 213ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2722e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 24/100
# 75/75 [==============================] - 16s 212ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 25/100
# 75/75 [==============================] - 16s 217ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 26/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 27/100
# 75/75 [==============================] - 16s 215ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 28/100
# 75/75 [==============================] - 16s 213ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 29/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 30/100
# 75/75 [==============================] - 16s 216ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 31/100
# 75/75 [==============================] - 16s 210ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 32/100
# 75/75 [==============================] - 16s 215ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 33/100
# 75/75 [==============================] - 16s 212ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 34/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 35/100
# 75/75 [==============================] - 16s 216ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 36/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2722e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 37/100
# 75/75 [==============================] - 16s 215ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 38/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2720e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 39/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 40/100
# 75/75 [==============================] - 16s 215ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2720e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 41/100
# 75/75 [==============================] - 16s 212ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 42/100
# 75/75 [==============================] - 16s 212ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 43/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2720e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 44/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 45/100
# 75/75 [==============================] - 16s 214ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2722e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 46/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 47/100
# 75/75 [==============================] - 16s 215ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 48/100
# 75/75 [==============================] - 16s 212ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 49/100
# 75/75 [==============================] - 16s 212ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 50/100
# 75/75 [==============================] - 16s 213ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 51/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 52/100
# 75/75 [==============================] - 16s 215ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 53/100
# 75/75 [==============================] - 16s 213ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2720e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 54/100
# 75/75 [==============================] - 16s 213ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 55/100
# 75/75 [==============================] - 16s 212ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2720e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 56/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 57/100
# 75/75 [==============================] - 16s 214ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 58/100
# 75/75 [==============================] - 16s 214ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 59/100
# 75/75 [==============================] - 16s 213ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 60/100
# 75/75 [==============================] - 16s 213ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 61/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 62/100
# 75/75 [==============================] - 16s 214ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 63/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 64/100
# 75/75 [==============================] - 16s 214ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 65/100
# 75/75 [==============================] - 16s 213ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 66/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 67/100
# 75/75 [==============================] - 16s 214ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 68/100
# 75/75 [==============================] - 16s 212ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 69/100
# 75/75 [==============================] - 16s 215ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 70/100
# 75/75 [==============================] - 16s 213ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 71/100
# 75/75 [==============================] - 16s 212ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 72/100
# 75/75 [==============================] - 16s 214ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 73/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 74/100
# 75/75 [==============================] - 16s 214ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 75/100
# 75/75 [==============================] - 16s 213ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 76/100
# 75/75 [==============================] - 16s 212ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 77/100
# 75/75 [==============================] - 19s 252ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 78/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2720e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 79/100
# 75/75 [==============================] - 16s 212ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 80/100
# 75/75 [==============================] - 16s 215ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 81/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 82/100
# 75/75 [==============================] - 16s 216ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 83/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 84/100
# 75/75 [==============================] - 16s 212ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 85/100
# 75/75 [==============================] - 16s 215ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 86/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 87/100
# 75/75 [==============================] - 16s 215ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 88/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2722e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 89/100
# 75/75 [==============================] - 16s 212ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 90/100
# 75/75 [==============================] - 16s 213ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 91/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 92/100
# 75/75 [==============================] - 16s 216ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 93/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 94/100
# 75/75 [==============================] - 16s 213ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 95/100
# 75/75 [==============================] - 16s 214ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2722e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 96/100
# 75/75 [==============================] - 16s 210ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 97/100
# 75/75 [==============================] - 16s 214ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 98/100
# 75/75 [==============================] - 16s 211ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 99/100
# 75/75 [==============================] - 16s 213ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04
# Epoch 100/100
# 75/75 [==============================] - 16s 213ms/step - loss: 15.2460 - accuracy: 2.1366e-04 - dice_coef: 4.2721e-04 - iou: 2.1461e-04 - iou_thresholded: 2.1461e-04 - val_loss: 15.2453 - val_accuracy: 2.5864e-04 - val_dice_coef: 5.1712e-04 - val_iou: 2.5959e-04 - val_iou_thresholded: 2.5959e-04

# %%
from keras_unet.utils import plot_segm_history

plot_segm_history(history)

# %%
y_pred = model.predict(X_test)

# %%
from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=X_test, mask_imgs=y_test, pred_imgs=y_pred, nm_img_to_plot=10)

# %%
loss, iou, iou_thresholded = model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 1s 336ms/step - loss: 15.2453 - accuracy: 2.5844e-04 - dice_coef: 4.8733e-04 - iou: 2.4395e-04 - iou_thresholded: 2.4395e-04
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4045514/357818279.py in <module>
# ----> 1 loss, iou, iou_thresholded = model.evaluate(X_test, y_test)
#
# ValueError: too many values to unpack (expected 3)
