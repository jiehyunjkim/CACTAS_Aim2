# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import os
import keras
from keras_unet.models import custom_unet
from sklearn.model_selection import train_test_split
# Out:
# 2023-03-23 23:39:28.777618: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# /home/jiehyun.kim001/miniconda3/envs/O/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# -----------------------------------------
# keras-unet init: TF version is >= 2.0.0 - using `tf.keras` instead of `Keras`
# -----------------------------------------

# %%
import tensorflow as tf

# %%
gpu_avail = tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_2311809/113432486.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# 2023-03-23 23:39:34.149369: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-23 23:39:34.155568: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-03-23 23:39:34.423529: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:4e:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2023-03-23 23:39:34.423571: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-03-23 23:39:34.434845: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-03-23 23:39:34.434880: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-03-23 23:39:34.435862: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-03-23 23:39:34.436278: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-03-23 23:39:34.436892: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-03-23 23:39:34.437778: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-03-23 23:39:34.438056: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-03-23 23:39:34.455846: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-23 23:39:34.457925: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-03-23 23:39:34.999838: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-03-23 23:39:34.999877: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-03-23 23:39:34.999883: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-03-23 23:39:35.007801: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:0 with 38425 MB memory) -> physical GPU (device: 0, name: A100-SXM4-40GB, pci bus id: 0000:4e:00.0, compute capability: 8.0)

# %%
gpu_avail
# Out:
# True

# %%
DATAPATH = '/raid/mpsych/CACTAS/DATA/ESUS/'
images_file = os.path.join(DATAPATH, 'images.npy')
labels_file = os.path.join(DATAPATH, 'labels.npy')

# %%
images = np.load(images_file)
labels = np.load(labels_file)

# %%
images.ndim, labels.ndim
# Out:
# (3, 3)

# %%
# full dataset does not have the last channel
images = images.reshape(images.shape[0],images.shape[1],images.shape[2],1)
labels = labels.reshape(labels.shape[0],labels.shape[1],labels.shape[2],1)

# %%
p = np.random.permutation(len(images))

# %%
images = images[p]
labels = labels[p]

# %%
images = images.astype(np.float64)
labels = labels.astype(np.float64)

# %%
for i in range(images.shape[0]):
    
    images[i] = (images[i] - images[i].min()) / (images[i].max() - images[i].min()) # normalize individually

# %%
images.shape
# Out:
# (766, 512, 512, 1)

# %%
labels.shape
# Out:
# (766, 512, 512, 1)

# %%
from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=images, mask_imgs=labels, nm_img_to_plot=3, figsize=5)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
X_train, X_val, y_train, y_val = train_test_split(images, labels, test_size=0.2, random_state=0)

# %%
#import json

# %%
#with open("images_data_v2.json", "r") as fp:
#    image_data = json.load(fp)
#with open("labels_data_v2.json", "r") as fp:
#    label_data = json.load(fp)

# %%
#image_data['82']
# Out:
# 12029

# %%
#label_data['82']
# Out:
# 12029

# %%
#X_train = images[0:image_data['82']]
#y_train = labels[0:label_data['82']]
#X_val = images[image_data['82']:]
#y_val = labels[label_data['82']:]

# %%
from keras_unet_collection import models, losses
import torch

model = models.swin_unet_2d((512, 512, 1), filter_num_begin=64,
                               n_labels=1, depth=4, stack_num_down=4, stack_num_up=4,
                               patch_size=(4, 4), num_heads=[4, 8, 16, 16],
                               window_size=[4, 2, 2, 2], num_mlp=512, 
                               output_activation='Sigmoid', shift_window=True, name='swin_unet')

#Softmax
# Out:
# 2023-03-23 23:39:57.804475: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:4e:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2023-03-23 23:39:57.809336: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-23 23:39:57.811953: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:4e:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2023-03-23 23:39:57.816775: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-23 23:39:57.816807: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-03-23 23:39:57.816812: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-03-23 23:39:57.816816: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-03-23 23:39:57.821677: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 38425 MB memory) -> physical GPU (device: 0, name: A100-SXM4-40GB, pci bus id: 0000:4e:00.0, compute capability: 8.0)
# WARNING:tensorflow:From /home/jiehyun.kim001/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.

# %%
model.summary()
# Out:
# Model: "swin_unet_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# patch_extract (patch_extract)   (None, 16384, 16)    0           input_1[0][0]
# __________________________________________________________________________________________________
# patch_embedding (patch_embeddin (None, 16384, 64)    1049664     patch_extract[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block (SwinTra (None, 16384, 64)    83460       patch_embedding[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_1 (SwinT (None, 16384, 64)    345604      swin_transformer_block[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_2 (SwinT (None, 16384, 64)    83460       swin_transformer_block_1[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_3 (SwinT (None, 16384, 64)    345604      swin_transformer_block_2[0][0]
# __________________________________________________________________________________________________
# patch_merging (patch_merging)   (None, 4096, 128)    32768       swin_transformer_block_3[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_4 (SwinT (None, 4096, 128)    198360      patch_merging[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_5 (SwinT (None, 4096, 128)    214744      swin_transformer_block_4[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_6 (SwinT (None, 4096, 128)    198360      swin_transformer_block_5[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_7 (SwinT (None, 4096, 128)    214744      swin_transformer_block_6[0][0]
# __________________________________________________________________________________________________
# patch_merging_1 (patch_merging) (None, 1024, 256)    131072      swin_transformer_block_7[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_8 (SwinT (None, 1024, 256)    527264      patch_merging_1[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_9 (SwinT (None, 1024, 256)    531360      swin_transformer_block_8[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_10 (Swin (None, 1024, 256)    527264      swin_transformer_block_9[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_11 (Swin (None, 1024, 256)    531360      swin_transformer_block_10[0][0]
# __________________________________________________________________________________________________
# patch_merging_2 (patch_merging) (None, 256, 512)     524288      swin_transformer_block_11[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_12 (Swin (None, 256, 512)     1578144     patch_merging_2[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_13 (Swin (None, 256, 512)     1579168     swin_transformer_block_12[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_14 (Swin (None, 256, 512)     1578144     swin_transformer_block_13[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_15 (Swin (None, 256, 512)     1579168     swin_transformer_block_14[0][0]
# __________________________________________________________________________________________________
# patch_expanding (patch_expandin (None, 1024, 256)    524288      swin_transformer_block_15[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_0 (Concatenate (None, 1024, 512)    0           patch_expanding[0][0]
#                                                                  swin_transformer_block_11[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_linear_proj_0  (None, 1024, 256)    131072      swin_unet_concat_0[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_16 (Swin (None, 1024, 256)    527264      swin_unet_concat_linear_proj_0[0]
# __________________________________________________________________________________________________
# swin_transformer_block_17 (Swin (None, 1024, 256)    531360      swin_transformer_block_16[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_18 (Swin (None, 1024, 256)    527264      swin_transformer_block_17[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_19 (Swin (None, 1024, 256)    531360      swin_transformer_block_18[0][0]
# __________________________________________________________________________________________________
# patch_expanding_1 (patch_expand (None, 4096, 128)    131072      swin_transformer_block_19[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_1 (Concatenate (None, 4096, 256)    0           patch_expanding_1[0][0]
#                                                                  swin_transformer_block_7[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_linear_proj_1  (None, 4096, 128)    32768       swin_unet_concat_1[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_20 (Swin (None, 4096, 128)    198432      swin_unet_concat_linear_proj_1[0]
# __________________________________________________________________________________________________
# swin_transformer_block_21 (Swin (None, 4096, 128)    214816      swin_transformer_block_20[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_22 (Swin (None, 4096, 128)    198432      swin_transformer_block_21[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_23 (Swin (None, 4096, 128)    214816      swin_transformer_block_22[0][0]
# __________________________________________________________________________________________________
# patch_expanding_2 (patch_expand (None, 16384, 64)    32768       swin_transformer_block_23[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_2 (Concatenate (None, 16384, 128)   0           patch_expanding_2[0][0]
#                                                                  swin_transformer_block_3[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_linear_proj_2  (None, 16384, 64)    8192        swin_unet_concat_2[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_24 (Swin (None, 16384, 64)    83096       swin_unet_concat_linear_proj_2[0]
# __________________________________________________________________________________________________
# swin_transformer_block_25 (Swin (None, 16384, 64)    148632      swin_transformer_block_24[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_26 (Swin (None, 16384, 64)    83096       swin_transformer_block_25[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_27 (Swin (None, 16384, 64)    148632      swin_transformer_block_26[0][0]
# __________________________________________________________________________________________________
# patch_expanding_3 (patch_expand (None, 512, 512, 16) 16384       swin_transformer_block_27[0][0]
# __________________________________________________________________________________________________
# swin_unet_output (Conv2D)       (None, 512, 512, 1)  17          patch_expanding_3[0][0]
# __________________________________________________________________________________________________
# swin_unet_output_activation (Ac (None, 512, 512, 1)  0           swin_unet_output[0][0]
# ==================================================================================================
# Total params: 16,137,761
# Trainable params: 15,397,025
# Non-trainable params: 740,736
# __________________________________________________________________________________________________

# %%
from tensorflow.keras import optimizers
from keras_unet.metrics import iou, iou_thresholded, dice_coef
from keras_unet_collection import losses

# %%
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr = 0.001),
              metrics=[iou, iou_thresholded])
# Out:
# /home/jiehyun.kim001/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %%
history = model.fit(X_train, 
                    y_train, 
                    batch_size=16,
                    epochs=100,
                    validation_data=(X_val, y_val))
# Out:
# 2023-03-23 23:40:11.163655: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-03-23 23:40:11.185170: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245645000 Hz
# Epoch 1/100
# 2023-03-23 23:40:36.032722: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-03-23 23:40:37.453357: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-03-23 23:40:37.453696: I tensorflow/stream_executor/cuda/cuda_blas.cc:1838] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-03-23 23:40:37.609019: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-03-23 23:40:38.785094: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8201
# 2023-03-23 23:40:40.412404: W tensorflow/stream_executor/gpu/asm_compiler.cc:191] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.0
# 2023-03-23 23:40:40.412429: W tensorflow/stream_executor/gpu/asm_compiler.cc:194] Used ptxas at ptxas
# 2023-03-23 23:40:40.413298: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Unimplemented: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 39/39 [==============================] - 66s 921ms/step - loss: 0.0678 - iou: 5.7052e-04 - iou_thresholded: 5.6336e-04 - val_loss: 0.0211 - val_iou: 5.6925e-04 - val_iou_thresholded: 5.1046e-04
# Epoch 2/100
# 39/39 [==============================] - 31s 790ms/step - loss: 0.0084 - iou: 0.0019 - iou_thresholded: 0.0023 - val_loss: 0.0056 - val_iou: 0.0063 - val_iou_thresholded: 0.0044
# Epoch 3/100
# 39/39 [==============================] - 31s 792ms/step - loss: 0.0040 - iou: 0.0093 - iou_thresholded: 0.0110 - val_loss: 0.0039 - val_iou: 0.0140 - val_iou_thresholded: 0.0283
# Epoch 4/100
# 39/39 [==============================] - 31s 789ms/step - loss: 0.0036 - iou: 0.0122 - iou_thresholded: 0.0144 - val_loss: 0.0036 - val_iou: 0.0084 - val_iou_thresholded: 0.0062
# Epoch 5/100
# 39/39 [==============================] - 31s 789ms/step - loss: 0.0031 - iou: 0.0179 - iou_thresholded: 0.0260 - val_loss: 0.0034 - val_iou: 0.0081 - val_iou_thresholded: 0.0024
# Epoch 6/100
# 39/39 [==============================] - 31s 794ms/step - loss: 0.0029 - iou: 0.0335 - iou_thresholded: 0.0458 - val_loss: 0.0031 - val_iou: 0.0162 - val_iou_thresholded: 0.0074
# Epoch 7/100
# 39/39 [==============================] - 31s 791ms/step - loss: 0.0028 - iou: 0.0438 - iou_thresholded: 0.0617 - val_loss: 0.0035 - val_iou: 0.0152 - val_iou_thresholded: 0.0133
# Epoch 8/100
# 39/39 [==============================] - 31s 796ms/step - loss: 0.0028 - iou: 0.0440 - iou_thresholded: 0.0517 - val_loss: 0.0027 - val_iou: 0.0385 - val_iou_thresholded: 0.0314
# Epoch 9/100
# 39/39 [==============================] - 31s 790ms/step - loss: 0.0022 - iou: 0.0675 - iou_thresholded: 0.0933 - val_loss: 0.0028 - val_iou: 0.0547 - val_iou_thresholded: 0.0642
# Epoch 10/100
# 39/39 [==============================] - 31s 788ms/step - loss: 0.0020 - iou: 0.0985 - iou_thresholded: 0.1371 - val_loss: 0.0025 - val_iou: 0.0823 - val_iou_thresholded: 0.0946
# Epoch 11/100
# 39/39 [==============================] - 31s 795ms/step - loss: 0.0021 - iou: 0.0989 - iou_thresholded: 0.1399 - val_loss: 0.0022 - val_iou: 0.0966 - val_iou_thresholded: 0.1312
# Epoch 12/100
# 39/39 [==============================] - 31s 790ms/step - loss: 0.0016 - iou: 0.1473 - iou_thresholded: 0.2231 - val_loss: 0.0021 - val_iou: 0.1213 - val_iou_thresholded: 0.1624
# Epoch 13/100
# 39/39 [==============================] - 31s 793ms/step - loss: 0.0013 - iou: 0.1905 - iou_thresholded: 0.2678 - val_loss: 0.0021 - val_iou: 0.1439 - val_iou_thresholded: 0.2095
# Epoch 14/100
# 39/39 [==============================] - 31s 792ms/step - loss: 0.0012 - iou: 0.2255 - iou_thresholded: 0.3100 - val_loss: 0.0018 - val_iou: 0.1864 - val_iou_thresholded: 0.2614
# Epoch 15/100
# 39/39 [==============================] - 31s 789ms/step - loss: 8.1216e-04 - iou: 0.2552 - iou_thresholded: 0.3295 - val_loss: 0.0015 - val_iou: 0.2468 - val_iou_thresholded: 0.2944
# Epoch 16/100
# 39/39 [==============================] - 31s 791ms/step - loss: 3.1468e-04 - iou: 0.2792 - iou_thresholded: 0.3571 - val_loss: 0.0012 - val_iou: 0.2082 - val_iou_thresholded: 0.3155
# Epoch 17/100
# 39/39 [==============================] - 31s 795ms/step - loss: -4.5511e-04 - iou: 0.2888 - iou_thresholded: 0.3563 - val_loss: 0.0030 - val_iou: 0.1441 - val_iou_thresholded: 0.1434
# Epoch 18/100
# 39/39 [==============================] - 31s 793ms/step - loss: 361.6724 - iou: 0.1056 - iou_thresholded: 0.1198 - val_loss: 4.2098 - val_iou: 6.2564e-04 - val_iou_thresholded: 6.2568e-04
# Epoch 19/100
# 39/39 [==============================] - 31s 793ms/step - loss: 10.0263 - iou: 0.0033 - iou_thresholded: 0.0032 - val_loss: 0.0991 - val_iou: 0.0049 - val_iou_thresholded: 0.0049
# Epoch 20/100
# 39/39 [==============================] - 31s 795ms/step - loss: 0.0448 - iou: 0.0034 - iou_thresholded: 0.0034 - val_loss: 0.0206 - val_iou: 0.0108 - val_iou_thresholded: 0.0109
# Epoch 21/100
# 39/39 [==============================] - 31s 792ms/step - loss: 0.0131 - iou: 0.0103 - iou_thresholded: 0.0112 - val_loss: 0.0127 - val_iou: 0.0167 - val_iou_thresholded: 0.0191
# Epoch 22/100
# 39/39 [==============================] - 31s 794ms/step - loss: 0.0086 - iou: 0.0183 - iou_thresholded: 0.0215 - val_loss: 0.0095 - val_iou: 0.0229 - val_iou_thresholded: 0.0303
# Epoch 23/100
# 39/39 [==============================] - 31s 794ms/step - loss: 0.0068 - iou: 0.0201 - iou_thresholded: 0.0245 - val_loss: 0.0083 - val_iou: 0.0262 - val_iou_thresholded: 0.0297
# Epoch 24/100
# 39/39 [==============================] - 31s 795ms/step - loss: 0.0059 - iou: 0.0240 - iou_thresholded: 0.0295 - val_loss: 0.0072 - val_iou: 0.0296 - val_iou_thresholded: 0.0371
# Epoch 25/100
# 39/39 [==============================] - 31s 795ms/step - loss: 0.0052 - iou: 0.0318 - iou_thresholded: 0.0396 - val_loss: 0.0068 - val_iou: 0.0328 - val_iou_thresholded: 0.0390
# Epoch 26/100
# 39/39 [==============================] - 31s 789ms/step - loss: 0.0047 - iou: 0.0363 - iou_thresholded: 0.0471 - val_loss: 0.0064 - val_iou: 0.0350 - val_iou_thresholded: 0.0410
# Epoch 27/100
# 39/39 [==============================] - 31s 795ms/step - loss: 0.0043 - iou: 0.0435 - iou_thresholded: 0.0565 - val_loss: 0.0059 - val_iou: 0.0364 - val_iou_thresholded: 0.0447
# Epoch 28/100
# 39/39 [==============================] - 31s 794ms/step - loss: 0.0040 - iou: 0.0467 - iou_thresholded: 0.0631 - val_loss: 0.0056 - val_iou: 0.0397 - val_iou_thresholded: 0.0483
# Epoch 29/100
# 39/39 [==============================] - 31s 795ms/step - loss: 0.0038 - iou: 0.0593 - iou_thresholded: 0.0818 - val_loss: 0.0056 - val_iou: 0.0354 - val_iou_thresholded: 0.0386
# Epoch 30/100
# 39/39 [==============================] - 31s 793ms/step - loss: 0.0036 - iou: 0.0544 - iou_thresholded: 0.0727 - val_loss: 0.0053 - val_iou: 0.0456 - val_iou_thresholded: 0.0536
# Epoch 31/100
# 39/39 [==============================] - 31s 792ms/step - loss: 0.0034 - iou: 0.0639 - iou_thresholded: 0.0841 - val_loss: 0.0051 - val_iou: 0.0425 - val_iou_thresholded: 0.0536
# Epoch 32/100
# 39/39 [==============================] - 31s 794ms/step - loss: 0.0032 - iou: 0.0725 - iou_thresholded: 0.0985 - val_loss: 0.0050 - val_iou: 0.0484 - val_iou_thresholded: 0.0521
# Epoch 33/100
# 39/39 [==============================] - 31s 793ms/step - loss: 0.0031 - iou: 0.0831 - iou_thresholded: 0.1110 - val_loss: 0.0048 - val_iou: 0.0561 - val_iou_thresholded: 0.0606
# Epoch 34/100
# 39/39 [==============================] - 31s 791ms/step - loss: 0.0030 - iou: 0.0787 - iou_thresholded: 0.1062 - val_loss: 0.0047 - val_iou: 0.0572 - val_iou_thresholded: 0.0660
# Epoch 35/100
# 39/39 [==============================] - 31s 794ms/step - loss: 0.0028 - iou: 0.0841 - iou_thresholded: 0.1124 - val_loss: 0.0048 - val_iou: 0.0552 - val_iou_thresholded: 0.0543
# Epoch 36/100
# 39/39 [==============================] - 31s 789ms/step - loss: 0.0027 - iou: 0.0898 - iou_thresholded: 0.1173 - val_loss: 0.0044 - val_iou: 0.0665 - val_iou_thresholded: 0.0757
# Epoch 37/100
# 39/39 [==============================] - 31s 794ms/step - loss: 0.0025 - iou: 0.1000 - iou_thresholded: 0.1366 - val_loss: 0.0042 - val_iou: 0.0741 - val_iou_thresholded: 0.0876
# Epoch 38/100
# 39/39 [==============================] - 31s 791ms/step - loss: 0.0024 - iou: 0.1018 - iou_thresholded: 0.1357 - val_loss: 0.0044 - val_iou: 0.0704 - val_iou_thresholded: 0.0733
# Epoch 39/100
# 39/39 [==============================] - 31s 795ms/step - loss: 0.0023 - iou: 0.1135 - iou_thresholded: 0.1548 - val_loss: 0.0039 - val_iou: 0.0827 - val_iou_thresholded: 0.1089
# Epoch 40/100
# 39/39 [==============================] - 31s 794ms/step - loss: 0.0023 - iou: 0.1261 - iou_thresholded: 0.1748 - val_loss: 0.0044 - val_iou: 0.0690 - val_iou_thresholded: 0.0698
# Epoch 41/100
# 39/39 [==============================] - 31s 792ms/step - loss: 0.0026 - iou: 0.1031 - iou_thresholded: 0.1351 - val_loss: 0.0039 - val_iou: 0.0766 - val_iou_thresholded: 0.0989
# Epoch 42/100
# 39/39 [==============================] - 31s 790ms/step - loss: 0.0024 - iou: 0.1196 - iou_thresholded: 0.1565 - val_loss: 0.0038 - val_iou: 0.0707 - val_iou_thresholded: 0.0882
# Epoch 43/100
# 39/39 [==============================] - 31s 791ms/step - loss: 0.0022 - iou: 0.1156 - iou_thresholded: 0.1549 - val_loss: 0.0037 - val_iou: 0.0858 - val_iou_thresholded: 0.1103
# Epoch 44/100
# 39/39 [==============================] - 31s 791ms/step - loss: 0.0021 - iou: 0.1199 - iou_thresholded: 0.1700 - val_loss: 0.0036 - val_iou: 0.0974 - val_iou_thresholded: 0.1264
# Epoch 45/100
# 39/39 [==============================] - 31s 791ms/step - loss: 0.0021 - iou: 0.1196 - iou_thresholded: 0.1648 - val_loss: 0.0036 - val_iou: 0.0888 - val_iou_thresholded: 0.1145
# Epoch 46/100
# 39/39 [==============================] - 31s 793ms/step - loss: 0.0019 - iou: 0.1378 - iou_thresholded: 0.1933 - val_loss: 0.0033 - val_iou: 0.1065 - val_iou_thresholded: 0.1396
# Epoch 47/100
# 39/39 [==============================] - 31s 793ms/step - loss: 0.0018 - iou: 0.1390 - iou_thresholded: 0.1910 - val_loss: 0.0040 - val_iou: 0.0855 - val_iou_thresholded: 0.0884
# Epoch 48/100
# 39/39 [==============================] - 31s 791ms/step - loss: 0.0021 - iou: 0.1189 - iou_thresholded: 0.1670 - val_loss: 0.0034 - val_iou: 0.0887 - val_iou_thresholded: 0.1123
# Epoch 49/100
# 39/39 [==============================] - 31s 791ms/step - loss: 0.0018 - iou: 0.1378 - iou_thresholded: 0.1843 - val_loss: 0.0035 - val_iou: 0.1018 - val_iou_thresholded: 0.1301
# Epoch 50/100
# 39/39 [==============================] - 31s 793ms/step - loss: 0.0015 - iou: 0.1506 - iou_thresholded: 0.2186 - val_loss: 0.0033 - val_iou: 0.1143 - val_iou_thresholded: 0.1353
# Epoch 51/100
# 39/39 [==============================] - 31s 792ms/step - loss: 0.0016 - iou: 0.1558 - iou_thresholded: 0.2094 - val_loss: 0.0033 - val_iou: 0.0934 - val_iou_thresholded: 0.1308
# Epoch 52/100
# 39/39 [==============================] - 31s 793ms/step - loss: 0.0016 - iou: 0.1507 - iou_thresholded: 0.2146 - val_loss: 0.0033 - val_iou: 0.1054 - val_iou_thresholded: 0.1290
# Epoch 53/100
# 39/39 [==============================] - 31s 789ms/step - loss: 0.0017 - iou: 0.1335 - iou_thresholded: 0.1836 - val_loss: 0.0032 - val_iou: 0.0925 - val_iou_thresholded: 0.1345
# Epoch 54/100
# 39/39 [==============================] - 31s 793ms/step - loss: 0.0018 - iou: 0.1330 - iou_thresholded: 0.1834 - val_loss: 0.0034 - val_iou: 0.0969 - val_iou_thresholded: 0.1653
# Epoch 55/100
# 39/39 [==============================] - 31s 795ms/step - loss: 0.0017 - iou: 0.1327 - iou_thresholded: 0.1811 - val_loss: 0.0034 - val_iou: 0.0983 - val_iou_thresholded: 0.1378
# Epoch 56/100
# 39/39 [==============================] - 31s 793ms/step - loss: 0.0014 - iou: 0.1427 - iou_thresholded: 0.2020 - val_loss: 0.0027 - val_iou: 0.1320 - val_iou_thresholded: 0.1628
# Epoch 57/100
# 39/39 [==============================] - 31s 795ms/step - loss: 0.0013 - iou: 0.1431 - iou_thresholded: 0.2141 - val_loss: 0.0030 - val_iou: 0.0913 - val_iou_thresholded: 0.1122
# Epoch 58/100
# 39/39 [==============================] - 31s 792ms/step - loss: 8.3994e-04 - iou: 0.1553 - iou_thresholded: 0.2173 - val_loss: 0.0027 - val_iou: 0.1363 - val_iou_thresholded: 0.1698
# Epoch 59/100
# 39/39 [==============================] - 31s 793ms/step - loss: 5.8842e-04 - iou: 0.1731 - iou_thresholded: 0.2383 - val_loss: 0.0031 - val_iou: 0.1344 - val_iou_thresholded: 0.1788
# Epoch 60/100
# 39/39 [==============================] - 31s 794ms/step - loss: 6.8159e-04 - iou: 0.1604 - iou_thresholded: 0.2250 - val_loss: 0.0038 - val_iou: 0.0587 - val_iou_thresholded: 0.0628
# Epoch 61/100
# 39/39 [==============================] - 31s 790ms/step - loss: 0.0015 - iou: 0.1076 - iou_thresholded: 0.1466 - val_loss: 0.0034 - val_iou: 0.0877 - val_iou_thresholded: 0.1260
# Epoch 62/100
# 39/39 [==============================] - 31s 789ms/step - loss: 9.8801e-04 - iou: 0.1354 - iou_thresholded: 0.1892 - val_loss: 0.0031 - val_iou: 0.0844 - val_iou_thresholded: 0.1099
# Epoch 63/100
# 39/39 [==============================] - 31s 793ms/step - loss: 8.2132e-04 - iou: 0.1297 - iou_thresholded: 0.1798 - val_loss: 0.0031 - val_iou: 0.0760 - val_iou_thresholded: 0.1064
# Epoch 64/100
# 39/39 [==============================] - 31s 795ms/step - loss: 5.8813e-04 - iou: 0.1143 - iou_thresholded: 0.1616 - val_loss: 0.0023 - val_iou: 0.1059 - val_iou_thresholded: 0.1484
# Epoch 65/100
# 39/39 [==============================] - 31s 792ms/step - loss: 8.0227e-04 - iou: 0.1099 - iou_thresholded: 0.1579 - val_loss: 0.0046 - val_iou: 0.0341 - val_iou_thresholded: 0.0331
# Epoch 66/100
# 39/39 [==============================] - 31s 791ms/step - loss: 7.3782e-04 - iou: 0.1124 - iou_thresholded: 0.1570 - val_loss: 0.0032 - val_iou: 0.0705 - val_iou_thresholded: 0.0828
# Epoch 67/100
# 39/39 [==============================] - 31s 791ms/step - loss: -1.6448e-04 - iou: 0.1186 - iou_thresholded: 0.1674 - val_loss: 0.0024 - val_iou: 0.0991 - val_iou_thresholded: 0.1162
# Epoch 68/100
# 39/39 [==============================] - 31s 794ms/step - loss: -5.7673e-04 - iou: 0.1325 - iou_thresholded: 0.1750 - val_loss: 0.0023 - val_iou: 0.0503 - val_iou_thresholded: 0.0662
# Epoch 69/100
# 39/39 [==============================] - 31s 793ms/step - loss: -0.0010 - iou: 0.1196 - iou_thresholded: 0.1721 - val_loss: 0.0018 - val_iou: 0.1030 - val_iou_thresholded: 0.1208
# Epoch 70/100
# 39/39 [==============================] - 31s 791ms/step - loss: -9.1028e-04 - iou: 0.1213 - iou_thresholded: 0.1625 - val_loss: 0.0047 - val_iou: 0.0485 - val_iou_thresholded: 0.0672
# Epoch 71/100
# 39/39 [==============================] - 31s 792ms/step - loss: 0.0013 - iou: 0.0761 - iou_thresholded: 0.1185 - val_loss: 0.0020 - val_iou: 0.0653 - val_iou_thresholded: 0.0972
# Epoch 72/100
# 39/39 [==============================] - 31s 795ms/step - loss: -2.0864e-04 - iou: 0.1095 - iou_thresholded: 0.1611 - val_loss: 0.0033 - val_iou: 0.0269 - val_iou_thresholded: 0.0385
# Epoch 73/100
# 39/39 [==============================] - 31s 792ms/step - loss: 0.0017 - iou: 0.0613 - iou_thresholded: 0.0914 - val_loss: 0.0019 - val_iou: 0.0596 - val_iou_thresholded: 0.0864
# Epoch 74/100
# 39/39 [==============================] - 31s 790ms/step - loss: -6.4676e-04 - iou: 0.1007 - iou_thresholded: 0.1434 - val_loss: 0.0016 - val_iou: 0.0825 - val_iou_thresholded: 0.1018
# Epoch 75/100
# 39/39 [==============================] - 31s 792ms/step - loss: -0.0017 - iou: 0.1023 - iou_thresholded: 0.1464 - val_loss: 9.9758e-04 - val_iou: 0.0839 - val_iou_thresholded: 0.0896
# Epoch 76/100
# 39/39 [==============================] - 31s 798ms/step - loss: -0.0015 - iou: 0.0864 - iou_thresholded: 0.1184 - val_loss: 0.0013 - val_iou: 0.0597 - val_iou_thresholded: 0.0871
# Epoch 77/100
# 39/39 [==============================] - 31s 796ms/step - loss: -0.0026 - iou: 0.1002 - iou_thresholded: 0.1498 - val_loss: 0.0021 - val_iou: 0.0360 - val_iou_thresholded: 0.0315
# Epoch 78/100
# 39/39 [==============================] - 31s 790ms/step - loss: -0.0021 - iou: 0.0895 - iou_thresholded: 0.1170 - val_loss: 9.6657e-04 - val_iou: 0.0727 - val_iou_thresholded: 0.0836
# Epoch 79/100
# 39/39 [==============================] - 31s 792ms/step - loss: -0.0043 - iou: 0.0963 - iou_thresholded: 0.1376 - val_loss: -2.8874e-04 - val_iou: 0.0588 - val_iou_thresholded: 0.1020
# Epoch 80/100
# 39/39 [==============================] - 31s 789ms/step - loss: -0.0012 - iou: 0.0609 - iou_thresholded: 0.0850 - val_loss: 0.0060 - val_iou: 0.0300 - val_iou_thresholded: 0.0355
# Epoch 81/100
# 39/39 [==============================] - 31s 793ms/step - loss: -7.8057e-04 - iou: 0.0729 - iou_thresholded: 0.0963 - val_loss: 0.0015 - val_iou: 0.0430 - val_iou_thresholded: 0.0802
# Epoch 82/100
# 39/39 [==============================] - 31s 789ms/step - loss: 0.0098 - iou: 0.0320 - iou_thresholded: 0.0470 - val_loss: 0.0038 - val_iou: 0.0410 - val_iou_thresholded: 0.0500
# Epoch 83/100
# 39/39 [==============================] - 31s 793ms/step - loss: 0.0025 - iou: 0.0532 - iou_thresholded: 0.0721 - val_loss: 0.0028 - val_iou: 0.0435 - val_iou_thresholded: 0.0702
# Epoch 84/100
# 39/39 [==============================] - 31s 789ms/step - loss: 0.0012 - iou: 0.0600 - iou_thresholded: 0.0912 - val_loss: 0.0016 - val_iou: 0.0520 - val_iou_thresholded: 0.0766
# Epoch 85/100
# 39/39 [==============================] - 31s 796ms/step - loss: -2.7742e-04 - iou: 0.0753 - iou_thresholded: 0.1063 - val_loss: 0.0024 - val_iou: 0.0499 - val_iou_thresholded: 0.0514
# Epoch 86/100
# 39/39 [==============================] - 33s 844ms/step - loss: -0.0015 - iou: 0.0741 - iou_thresholded: 0.0952 - val_loss: -3.4250e-04 - val_iou: 0.0529 - val_iou_thresholded: 0.0809
# Epoch 87/100
# 39/39 [==============================] - 31s 796ms/step - loss: -0.0033 - iou: 0.0733 - iou_thresholded: 0.1104 - val_loss: -6.2656e-04 - val_iou: 0.0527 - val_iou_thresholded: 0.0829
# Epoch 88/100
# 39/39 [==============================] - 31s 795ms/step - loss: -0.0058 - iou: 0.0780 - iou_thresholded: 0.1177 - val_loss: -0.0030 - val_iou: 0.0439 - val_iou_thresholded: 0.0826
# Epoch 89/100
# 39/39 [==============================] - 31s 791ms/step - loss: -0.0085 - iou: 0.0797 - iou_thresholded: 0.1139 - val_loss: -0.0044 - val_iou: 0.0555 - val_iou_thresholded: 0.0763
# Epoch 90/100
# 39/39 [==============================] - 31s 791ms/step - loss: -0.0095 - iou: 0.0725 - iou_thresholded: 0.1027 - val_loss: -0.0030 - val_iou: 0.0694 - val_iou_thresholded: 0.0756
# Epoch 91/100
# 39/39 [==============================] - 31s 795ms/step - loss: -0.0089 - iou: 0.0658 - iou_thresholded: 0.0952 - val_loss: 0.0012 - val_iou: 0.0169 - val_iou_thresholded: 0.0495
# Epoch 92/100
# 39/39 [==============================] - 31s 792ms/step - loss: -0.0042 - iou: 0.0610 - iou_thresholded: 0.0808 - val_loss: -0.0036 - val_iou: 0.0373 - val_iou_thresholded: 0.0353
# Epoch 93/100
# 39/39 [==============================] - 31s 791ms/step - loss: -0.0160 - iou: 0.0631 - iou_thresholded: 0.0834 - val_loss: -0.0087 - val_iou: 0.0266 - val_iou_thresholded: 0.0339
# Epoch 94/100
# 39/39 [==============================] - 31s 792ms/step - loss: -0.0238 - iou: 0.0633 - iou_thresholded: 0.0902 - val_loss: -0.0119 - val_iou: 0.0445 - val_iou_thresholded: 0.0611
# Epoch 95/100
# 39/39 [==============================] - 31s 791ms/step - loss: -0.0237 - iou: 0.0652 - iou_thresholded: 0.1014 - val_loss: -0.0128 - val_iou: 0.0206 - val_iou_thresholded: 0.0311
# Epoch 96/100
# 39/39 [==============================] - 31s 792ms/step - loss: -0.0117 - iou: 0.0476 - iou_thresholded: 0.0603 - val_loss: 0.0459 - val_iou: 0.0015 - val_iou_thresholded: 0.0012
# Epoch 97/100
# 39/39 [==============================] - 31s 790ms/step - loss: 0.0092 - iou: 0.0150 - iou_thresholded: 0.0176 - val_loss: 0.0051 - val_iou: 0.0154 - val_iou_thresholded: 0.0145
# Epoch 98/100
# 39/39 [==============================] - 31s 795ms/step - loss: 0.0038 - iou: 0.0255 - iou_thresholded: 0.0301 - val_loss: 0.0039 - val_iou: 0.0203 - val_iou_thresholded: 0.0223
# Epoch 99/100
# 39/39 [==============================] - 31s 794ms/step - loss: 0.0029 - iou: 0.0284 - iou_thresholded: 0.0358 - val_loss: 0.0035 - val_iou: 0.0285 - val_iou_thresholded: 0.0344
# Epoch 100/100
# 39/39 [==============================] - 31s 795ms/step - loss: 0.0023 - iou: 0.0376 - iou_thresholded: 0.0476 - val_loss: 0.0033 - val_iou: 0.0259 - val_iou_thresholded: 0.0207

# %%
from keras_unet.utils import plot_segm_history

plot_segm_history(history)

# %%
y_pred = model.predict(X_val)

# %%
from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=X_val, mask_imgs=y_val, pred_imgs=y_pred, nm_img_to_plot=10)

# %%
loss, iou, iou_thresholded = model.evaluate(X_val, y_val)
# Out:
# 5/5 [==============================] - 2s 419ms/step - loss: 0.0033 - iou: 0.0291 - iou_thresholded: 0.0249
