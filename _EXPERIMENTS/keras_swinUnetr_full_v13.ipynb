# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import os
import keras
from keras_unet.models import custom_unet
from sklearn.model_selection import train_test_split
# Out:
# 2023-03-03 22:05:22.056953: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# /home/jiehyun.kim001/miniconda3/envs/O/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# -----------------------------------------
# keras-unet init: TF version is >= 2.0.0 - using `tf.keras` instead of `Keras`
# -----------------------------------------

# %%
import tensorflow as tf

# %%
gpu_avail = tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_1203561/113432486.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# 2023-03-03 22:05:27.023973: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-03 22:05:27.026314: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-03-03 22:05:27.153199: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:47:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2023-03-03 22:05:27.153243: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-03-03 22:05:27.168258: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-03-03 22:05:27.168295: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-03-03 22:05:27.173357: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-03-03 22:05:27.175807: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-03-03 22:05:27.178219: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-03-03 22:05:27.181977: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-03-03 22:05:27.182818: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-03-03 22:05:27.188444: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-03 22:05:27.188662: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-03-03 22:05:27.848731: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-03-03 22:05:27.848790: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-03-03 22:05:27.848796: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-03-03 22:05:27.858370: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:0 with 38425 MB memory) -> physical GPU (device: 0, name: A100-SXM4-40GB, pci bus id: 0000:47:00.0, compute capability: 8.0)

# %%
gpu_avail
# Out:
# True

# %%
DATAPATH = '/raid/mpsych/CACTAS/DATA/ESUS/'
images_file = os.path.join(DATAPATH, 'image.npy')
labels_file = os.path.join(DATAPATH, 'label.npy')

# %%
images = np.load(images_file)
labels = np.load(labels_file)

# %%
images.ndim, labels.ndim
# Out:
# (3, 3)

# %%
# full dataset does not have the last channel
images = images.reshape(images.shape[0],images.shape[1],images.shape[2],1)
labels = labels.reshape(labels.shape[0],labels.shape[1],labels.shape[2],1)

# %%
p = np.random.permutation(len(images))

# %%
images = images[p]
labels = labels[p]

# %%
images = images.astype(np.float64)
labels = labels.astype(np.float64)

# %%
for i in range(images.shape[0]):
    
    images[i] = (images[i] - images[i].min()) / (images[i].max() - images[i].min()) # normalize individually

# %%
images.shape
# Out:
# (14893, 512, 512, 1)

# %%
labels.shape
# Out:
# (14893, 512, 512, 1)

# %%
from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=images, mask_imgs=labels, nm_img_to_plot=3, figsize=5)

# %%
#X_train, X_val, y_train, y_val = train_test_split(images, labels, test_size=0.2, random_state=0)

# %%
import json

# %%
with open("images_data_v2.json", "r") as fp:
    image_data = json.load(fp)
with open("labels_data_v2.json", "r") as fp:
    label_data = json.load(fp)

# %%
image_data['82']
# Out:
# 12029

# %%
label_data['82']
# Out:
# 12029

# %%
X_train = images[0:image_data['82']]
y_train = labels[0:label_data['82']]
X_val = images[image_data['82']:]
y_val = labels[label_data['82']:]

# %%
from keras_unet_collection import models, losses
import torch

model = models.swin_unet_2d((512, 512, 1), filter_num_begin=64,
                               n_labels=1, depth=4, stack_num_down=4, stack_num_up=4,
                               patch_size=(4, 4), num_heads=[4, 8, 16, 16],
                               window_size=[4, 2, 2, 2], num_mlp=512, 
                               output_activation='Sigmoid', shift_window=True, name='swin_unet')

#Softmax
# Out:
# 2023-03-03 22:06:15.458998: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:47:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2023-03-03 22:06:15.463900: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-03 22:06:15.466592: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:47:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2023-03-03 22:06:15.471480: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-03 22:06:15.471521: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-03-03 22:06:15.471526: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-03-03 22:06:15.471530: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-03-03 22:06:15.476431: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 38425 MB memory) -> physical GPU (device: 0, name: A100-SXM4-40GB, pci bus id: 0000:47:00.0, compute capability: 8.0)
# WARNING:tensorflow:From /home/jiehyun.kim001/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.

# %%
model.summary()
# Out:
# Model: "swin_unet_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# patch_extract (patch_extract)   (None, 16384, 16)    0           input_1[0][0]
# __________________________________________________________________________________________________
# patch_embedding (patch_embeddin (None, 16384, 64)    1049664     patch_extract[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block (SwinTra (None, 16384, 64)    83460       patch_embedding[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_1 (SwinT (None, 16384, 64)    345604      swin_transformer_block[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_2 (SwinT (None, 16384, 64)    83460       swin_transformer_block_1[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_3 (SwinT (None, 16384, 64)    345604      swin_transformer_block_2[0][0]
# __________________________________________________________________________________________________
# patch_merging (patch_merging)   (None, 4096, 128)    32768       swin_transformer_block_3[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_4 (SwinT (None, 4096, 128)    198360      patch_merging[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_5 (SwinT (None, 4096, 128)    214744      swin_transformer_block_4[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_6 (SwinT (None, 4096, 128)    198360      swin_transformer_block_5[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_7 (SwinT (None, 4096, 128)    214744      swin_transformer_block_6[0][0]
# __________________________________________________________________________________________________
# patch_merging_1 (patch_merging) (None, 1024, 256)    131072      swin_transformer_block_7[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_8 (SwinT (None, 1024, 256)    527264      patch_merging_1[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_9 (SwinT (None, 1024, 256)    531360      swin_transformer_block_8[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_10 (Swin (None, 1024, 256)    527264      swin_transformer_block_9[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_11 (Swin (None, 1024, 256)    531360      swin_transformer_block_10[0][0]
# __________________________________________________________________________________________________
# patch_merging_2 (patch_merging) (None, 256, 512)     524288      swin_transformer_block_11[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_12 (Swin (None, 256, 512)     1578144     patch_merging_2[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_13 (Swin (None, 256, 512)     1579168     swin_transformer_block_12[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_14 (Swin (None, 256, 512)     1578144     swin_transformer_block_13[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_15 (Swin (None, 256, 512)     1579168     swin_transformer_block_14[0][0]
# __________________________________________________________________________________________________
# patch_expanding (patch_expandin (None, 1024, 256)    524288      swin_transformer_block_15[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_0 (Concatenate (None, 1024, 512)    0           patch_expanding[0][0]
#                                                                  swin_transformer_block_11[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_linear_proj_0  (None, 1024, 256)    131072      swin_unet_concat_0[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_16 (Swin (None, 1024, 256)    527264      swin_unet_concat_linear_proj_0[0]
# __________________________________________________________________________________________________
# swin_transformer_block_17 (Swin (None, 1024, 256)    531360      swin_transformer_block_16[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_18 (Swin (None, 1024, 256)    527264      swin_transformer_block_17[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_19 (Swin (None, 1024, 256)    531360      swin_transformer_block_18[0][0]
# __________________________________________________________________________________________________
# patch_expanding_1 (patch_expand (None, 4096, 128)    131072      swin_transformer_block_19[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_1 (Concatenate (None, 4096, 256)    0           patch_expanding_1[0][0]
#                                                                  swin_transformer_block_7[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_linear_proj_1  (None, 4096, 128)    32768       swin_unet_concat_1[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_20 (Swin (None, 4096, 128)    198432      swin_unet_concat_linear_proj_1[0]
# __________________________________________________________________________________________________
# swin_transformer_block_21 (Swin (None, 4096, 128)    214816      swin_transformer_block_20[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_22 (Swin (None, 4096, 128)    198432      swin_transformer_block_21[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_23 (Swin (None, 4096, 128)    214816      swin_transformer_block_22[0][0]
# __________________________________________________________________________________________________
# patch_expanding_2 (patch_expand (None, 16384, 64)    32768       swin_transformer_block_23[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_2 (Concatenate (None, 16384, 128)   0           patch_expanding_2[0][0]
#                                                                  swin_transformer_block_3[0][0]
# __________________________________________________________________________________________________
# swin_unet_concat_linear_proj_2  (None, 16384, 64)    8192        swin_unet_concat_2[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_24 (Swin (None, 16384, 64)    83096       swin_unet_concat_linear_proj_2[0]
# __________________________________________________________________________________________________
# swin_transformer_block_25 (Swin (None, 16384, 64)    148632      swin_transformer_block_24[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_26 (Swin (None, 16384, 64)    83096       swin_transformer_block_25[0][0]
# __________________________________________________________________________________________________
# swin_transformer_block_27 (Swin (None, 16384, 64)    148632      swin_transformer_block_26[0][0]
# __________________________________________________________________________________________________
# patch_expanding_3 (patch_expand (None, 512, 512, 16) 16384       swin_transformer_block_27[0][0]
# __________________________________________________________________________________________________
# swin_unet_output (Conv2D)       (None, 512, 512, 1)  17          patch_expanding_3[0][0]
# __________________________________________________________________________________________________
# swin_unet_output_activation (Ac (None, 512, 512, 1)  0           swin_unet_output[0][0]
# ==================================================================================================
# Total params: 16,137,761
# Trainable params: 15,397,025
# Non-trainable params: 740,736
# __________________________________________________________________________________________________

# %%
from tensorflow.keras import optimizers
from keras_unet.metrics import iou, iou_thresholded, dice_coef
from keras_unet_collection import losses

# %%
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr = 0.001),
              metrics=[iou, iou_thresholded])
# Out:
# /home/jiehyun.kim001/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %%
history = model.fit(X_train, 
                    y_train, 
                    batch_size=16,
                    epochs=100,
                    validation_data=(X_val, y_val))
# Out:
# 2023-03-03 22:06:38.952257: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-03-03 22:06:38.973170: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245645000 Hz
# Epoch 1/100
# 2023-03-03 22:07:03.424870: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-03-03 22:07:04.417250: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-03-03 22:07:04.417617: I tensorflow/stream_executor/cuda/cuda_blas.cc:1838] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-03-03 22:07:04.556267: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-03-03 22:07:05.359600: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8201
# 2023-03-03 22:07:06.366999: W tensorflow/stream_executor/gpu/asm_compiler.cc:191] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.0
# 2023-03-03 22:07:06.367025: W tensorflow/stream_executor/gpu/asm_compiler.cc:194] Used ptxas at ptxas
# 2023-03-03 22:07:06.367419: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Unimplemented: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 752/752 [==============================] - 636s 808ms/step - loss: 118.4950 - iou: 0.3624 - iou_thresholded: 0.3710 - val_loss: 5.2258 - val_iou: 0.3153 - val_iou_thresholded: 0.3159
# Epoch 2/100
# 752/752 [==============================] - 598s 795ms/step - loss: 0.9377 - iou: 0.0935 - iou_thresholded: 0.0943 - val_loss: 0.0057 - val_iou: 0.0091 - val_iou_thresholded: 0.0097
# Epoch 3/100
# 752/752 [==============================] - 598s 795ms/step - loss: 0.0061 - iou: 0.0734 - iou_thresholded: 0.0764 - val_loss: 0.0024 - val_iou: 0.1296 - val_iou_thresholded: 0.1621
# Epoch 4/100
# 752/752 [==============================] - 601s 800ms/step - loss: 0.0017 - iou: 0.0341 - iou_thresholded: 0.0691 - val_loss: 0.0012 - val_iou: 0.1341 - val_iou_thresholded: 0.3577
# Epoch 5/100
# 752/752 [==============================] - 598s 795ms/step - loss: 9.4645e-04 - iou: 0.0151 - iou_thresholded: 0.1034 - val_loss: 6.5872e-04 - val_iou: 0.0069 - val_iou_thresholded: 0.0919
# Epoch 6/100
# 752/752 [==============================] - 598s 795ms/step - loss: 6.1901e-04 - iou: 0.0120 - iou_thresholded: 0.1957 - val_loss: 4.7392e-04 - val_iou: 0.0115 - val_iou_thresholded: 0.2755
# Epoch 7/100
# 752/752 [==============================] - 598s 795ms/step - loss: 4.4848e-04 - iou: 0.0107 - iou_thresholded: 0.2657 - val_loss: 3.7085e-04 - val_iou: 0.0211 - val_iou_thresholded: 0.3702
# Epoch 8/100
# 752/752 [==============================] - 598s 796ms/step - loss: 3.6988e-04 - iou: 0.0161 - iou_thresholded: 0.3708 - val_loss: 3.0862e-04 - val_iou: 0.0037 - val_iou_thresholded: 0.3146
# Epoch 9/100
# 752/752 [==============================] - 598s 796ms/step - loss: 3.0852e-04 - iou: 0.0134 - iou_thresholded: 0.4247 - val_loss: 2.7353e-04 - val_iou: 0.0042 - val_iou_thresholded: 0.3641
# Epoch 10/100
# 752/752 [==============================] - 601s 799ms/step - loss: 2.8367e-04 - iou: 0.0136 - iou_thresholded: 0.4289 - val_loss: 2.4613e-04 - val_iou: 0.0059 - val_iou_thresholded: 0.3996
# Epoch 11/100
# 752/752 [==============================] - 598s 795ms/step - loss: 2.6966e-04 - iou: 0.0121 - iou_thresholded: 0.4479 - val_loss: 2.7646e-04 - val_iou: 0.0509 - val_iou_thresholded: 0.4069
# Epoch 12/100
# 752/752 [==============================] - 598s 795ms/step - loss: 2.6733e-04 - iou: 0.0143 - iou_thresholded: 0.4300 - val_loss: 2.4376e-04 - val_iou: 0.0189 - val_iou_thresholded: 0.4069
# Epoch 13/100
# 752/752 [==============================] - 598s 795ms/step - loss: 0.0011 - iou: 0.0128 - iou_thresholded: 0.4453 - val_loss: 4.1271 - val_iou: 0.4069 - val_iou_thresholded: 0.4069
# Epoch 14/100
# 752/752 [==============================] - 598s 795ms/step - loss: 103.5078 - iou: 0.0762 - iou_thresholded: 0.0763 - val_loss: 0.1962 - val_iou: 0.0049 - val_iou_thresholded: 0.0049
# Epoch 15/100
# 752/752 [==============================] - 599s 796ms/step - loss: 0.1210 - iou: 0.0531 - iou_thresholded: 0.0531 - val_loss: 0.0618 - val_iou: 0.0138 - val_iou_thresholded: 0.0138
# Epoch 16/100
# 752/752 [==============================] - 602s 801ms/step - loss: 0.0417 - iou: 0.0285 - iou_thresholded: 0.0288 - val_loss: 0.0230 - val_iou: 0.0065 - val_iou_thresholded: 0.0065
# Epoch 17/100
# 752/752 [==============================] - 598s 796ms/step - loss: 0.0171 - iou: 0.0485 - iou_thresholded: 0.0495 - val_loss: 0.0097 - val_iou: 0.0652 - val_iou_thresholded: 0.0648
# Epoch 18/100
# 752/752 [==============================] - 598s 795ms/step - loss: 0.0068 - iou: 0.0352 - iou_thresholded: 0.0372 - val_loss: 0.0043 - val_iou: 0.0717 - val_iou_thresholded: 0.0813
# Epoch 19/100
# 752/752 [==============================] - 598s 796ms/step - loss: 0.0035 - iou: 0.0196 - iou_thresholded: 0.0276 - val_loss: 0.0025 - val_iou: 0.0310 - val_iou_thresholded: 0.0575
# Epoch 20/100
# 752/752 [==============================] - 598s 795ms/step - loss: 0.0021 - iou: 0.0155 - iou_thresholded: 0.0348 - val_loss: 0.0014 - val_iou: 0.0216 - val_iou_thresholded: 0.0648
# Epoch 21/100
# 752/752 [==============================] - 598s 796ms/step - loss: 0.0117 - iou: 0.0376 - iou_thresholded: 0.0784 - val_loss: 0.0197 - val_iou: 0.0054 - val_iou_thresholded: 0.0054
# Epoch 22/100
# 752/752 [==============================] - 601s 799ms/step - loss: 0.0031 - iou: 0.0210 - iou_thresholded: 0.0604 - val_loss: 8.9993e-04 - val_iou: 0.0084 - val_iou_thresholded: 0.0646
# Epoch 23/100
# 752/752 [==============================] - 598s 796ms/step - loss: 7.6838e-04 - iou: 0.0113 - iou_thresholded: 0.1558 - val_loss: 5.4951e-04 - val_iou: 0.0069 - val_iou_thresholded: 0.1662
# Epoch 24/100
# 752/752 [==============================] - 597s 794ms/step - loss: 5.1480e-04 - iou: 0.0135 - iou_thresholded: 0.2668 - val_loss: 4.0295e-04 - val_iou: 0.0095 - val_iou_thresholded: 0.3242
# Epoch 25/100
# 752/752 [==============================] - 598s 795ms/step - loss: 4.0706e-04 - iou: 0.0207 - iou_thresholded: 0.3581 - val_loss: 3.5662e-04 - val_iou: 0.0042 - val_iou_thresholded: 0.0787
# Epoch 26/100
# 752/752 [==============================] - 598s 795ms/step - loss: 3.4517e-04 - iou: 0.0168 - iou_thresholded: 0.4094 - val_loss: 3.2417e-04 - val_iou: 0.0354 - val_iou_thresholded: 0.4069
# Epoch 27/100
# 752/752 [==============================] - 598s 795ms/step - loss: 3.2214e-04 - iou: 0.0188 - iou_thresholded: 0.4274 - val_loss: 2.7093e-04 - val_iou: 0.0072 - val_iou_thresholded: 0.4041
# Epoch 28/100
# 752/752 [==============================] - 601s 799ms/step - loss: 2.9377e-04 - iou: 0.0230 - iou_thresholded: 0.4415 - val_loss: 2.6169e-04 - val_iou: 0.0152 - val_iou_thresholded: 0.4069
# Epoch 29/100
# 752/752 [==============================] - 598s 796ms/step - loss: 3145.5813 - iou: 0.2207 - iou_thresholded: 0.2684 - val_loss: 6.2464 - val_iou: 0.0081 - val_iou_thresholded: 0.0081
# Epoch 30/100
# 752/752 [==============================] - 598s 795ms/step - loss: 4.7834 - iou: 0.1435 - iou_thresholded: 0.1435 - val_loss: 1.7077 - val_iou: 0.0099 - val_iou_thresholded: 0.0099
# Epoch 31/100
# 752/752 [==============================] - 598s 795ms/step - loss: 2.7037 - iou: 0.1400 - iou_thresholded: 0.1400 - val_loss: 0.9692 - val_iou: 0.0073 - val_iou_thresholded: 0.0073
# Epoch 32/100
# 752/752 [==============================] - 598s 795ms/step - loss: 1.4986 - iou: 0.0917 - iou_thresholded: 0.0917 - val_loss: 0.9115 - val_iou: 0.0374 - val_iou_thresholded: 0.0374
# Epoch 33/100
# 752/752 [==============================] - 598s 795ms/step - loss: 2.7893 - iou: 0.1034 - iou_thresholded: 0.1034 - val_loss: 0.3884 - val_iou: 0.0246 - val_iou_thresholded: 0.0245
# Epoch 34/100
# 752/752 [==============================] - 601s 799ms/step - loss: 0.6674 - iou: 0.0702 - iou_thresholded: 0.0703 - val_loss: 0.1530 - val_iou: 0.0152 - val_iou_thresholded: 0.0152
# Epoch 35/100
# 752/752 [==============================] - 598s 795ms/step - loss: 0.0992 - iou: 0.0191 - iou_thresholded: 0.0191 - val_loss: 0.0454 - val_iou: 0.0089 - val_iou_thresholded: 0.0089
# Epoch 36/100
# 752/752 [==============================] - 599s 796ms/step - loss: 5.2330 - iou: 0.0938 - iou_thresholded: 0.0938 - val_loss: 0.0754 - val_iou: 0.0087 - val_iou_thresholded: 0.0087
# Epoch 37/100
# 752/752 [==============================] - 598s 796ms/step - loss: 0.0452 - iou: 0.0085 - iou_thresholded: 0.0085 - val_loss: 0.0218 - val_iou: 0.0036 - val_iou_thresholded: 0.0036
# Epoch 38/100
# 752/752 [==============================] - 598s 796ms/step - loss: 0.0170 - iou: 0.0106 - iou_thresholded: 0.0107 - val_loss: 0.0115 - val_iou: 0.0227 - val_iou_thresholded: 0.0228
# Epoch 39/100
# 752/752 [==============================] - 599s 796ms/step - loss: 0.0091 - iou: 0.0155 - iou_thresholded: 0.0160 - val_loss: 0.0065 - val_iou: 0.0083 - val_iou_thresholded: 0.0086
# Epoch 40/100
# 752/752 [==============================] - 601s 799ms/step - loss: 0.0051 - iou: 0.0115 - iou_thresholded: 0.0124 - val_loss: 0.0037 - val_iou: 0.0152 - val_iou_thresholded: 0.0172
# Epoch 41/100
# 752/752 [==============================] - 598s 795ms/step - loss: 0.0032 - iou: 0.0141 - iou_thresholded: 0.0168 - val_loss: 0.0024 - val_iou: 0.0113 - val_iou_thresholded: 0.0149
# Epoch 42/100
# 752/752 [==============================] - 598s 795ms/step - loss: 0.0021 - iou: 0.0166 - iou_thresholded: 0.0225 - val_loss: 0.0016 - val_iou: 0.0090 - val_iou_thresholded: 0.0127
# Epoch 43/100
# 752/752 [==============================] - 599s 796ms/step - loss: 0.0013 - iou: 0.0164 - iou_thresholded: 0.0277 - val_loss: 0.0013 - val_iou: 0.0276 - val_iou_thresholded: 0.0438
# Epoch 44/100
# 752/752 [==============================] - 598s 795ms/step - loss: 0.0012 - iou: 0.0307 - iou_thresholded: 0.0485 - val_loss: 8.3977e-04 - val_iou: 0.0451 - val_iou_thresholded: 0.1395
# Epoch 45/100
# 752/752 [==============================] - 598s 796ms/step - loss: 6.4932e-04 - iou: 0.0176 - iou_thresholded: 0.0623 - val_loss: 0.0014 - val_iou: 0.0089 - val_iou_thresholded: 0.0239
# Epoch 46/100
# 752/752 [==============================] - 601s 799ms/step - loss: 5.5992e-04 - iou: 0.0244 - iou_thresholded: 0.1036 - val_loss: 9.6416e-04 - val_iou: 0.0104 - val_iou_thresholded: 0.0355
# Epoch 47/100
# 752/752 [==============================] - 598s 795ms/step - loss: 7083.4419 - iou: 0.0579 - iou_thresholded: 0.0583 - val_loss: 1.8237 - val_iou: 0.0033 - val_iou_thresholded: 0.0033
# Epoch 48/100
# 752/752 [==============================] - 599s 796ms/step - loss: 1.4257 - iou: 0.0301 - iou_thresholded: 0.0301 - val_loss: 0.5823 - val_iou: 0.0195 - val_iou_thresholded: 0.0195
# Epoch 49/100
# 752/752 [==============================] - 598s 795ms/step - loss: 1.9612 - iou: 0.1044 - iou_thresholded: 0.1044 - val_loss: 0.2734 - val_iou: 0.0095 - val_iou_thresholded: 0.0095
# Epoch 50/100
# 752/752 [==============================] - 598s 796ms/step - loss: 0.2465 - iou: 0.0643 - iou_thresholded: 0.0646 - val_loss: 0.1743 - val_iou: 0.2872 - val_iou_thresholded: 0.2871
# Epoch 51/100
# 752/752 [==============================] - 599s 796ms/step - loss: 0.1232 - iou: 0.0356 - iou_thresholded: 0.0357 - val_loss: 0.0518 - val_iou: 0.0097 - val_iou_thresholded: 0.0097
# Epoch 52/100
# 752/752 [==============================] - 602s 801ms/step - loss: 0.0657 - iou: 0.0323 - iou_thresholded: 0.0324 - val_loss: 0.0261 - val_iou: 0.0119 - val_iou_thresholded: 0.0120
# Epoch 53/100
# 752/752 [==============================] - 599s 796ms/step - loss: 0.0313 - iou: 0.0263 - iou_thresholded: 0.0265 - val_loss: 0.0261 - val_iou: 0.0151 - val_iou_thresholded: 0.0152
# Epoch 54/100
# 752/752 [==============================] - 598s 796ms/step - loss: 0.0143 - iou: 0.0123 - iou_thresholded: 0.0124 - val_loss: 0.0088 - val_iou: 0.0059 - val_iou_thresholded: 0.0061
# Epoch 55/100
# 752/752 [==============================] - 599s 796ms/step - loss: 0.0087 - iou: 0.0143 - iou_thresholded: 0.0147 - val_loss: 0.0059 - val_iou: 0.0230 - val_iou_thresholded: 0.0240
# Epoch 56/100
# 752/752 [==============================] - 598s 795ms/step - loss: 2104.5835 - iou: 0.1560 - iou_thresholded: 0.1563 - val_loss: 135.9517 - val_iou: 0.4069 - val_iou_thresholded: 0.4069
# Epoch 57/100
# 752/752 [==============================] - 598s 795ms/step - loss: 8.4432 - iou: 0.0479 - iou_thresholded: 0.0479 - val_loss: 1.6454 - val_iou: 0.0029 - val_iou_thresholded: 0.0029
# Epoch 58/100
# 752/752 [==============================] - 601s 800ms/step - loss: 26.9940 - iou: 0.0975 - iou_thresholded: 0.0975 - val_loss: 2.6933 - val_iou: 0.0107 - val_iou_thresholded: 0.0107
# Epoch 59/100
# 752/752 [==============================] - 598s 796ms/step - loss: 1.3381 - iou: 0.0169 - iou_thresholded: 0.0169 - val_loss: 0.3751 - val_iou: 0.0030 - val_iou_thresholded: 0.0030
# Epoch 60/100
# 752/752 [==============================] - 599s 796ms/step - loss: 0.2624 - iou: 0.0135 - iou_thresholded: 0.0135 - val_loss: 0.1192 - val_iou: 0.0049 - val_iou_thresholded: 0.0049
# Epoch 61/100
# 752/752 [==============================] - 598s 796ms/step - loss: 0.0933 - iou: 0.0116 - iou_thresholded: 0.0116 - val_loss: 0.0653 - val_iou: 0.0204 - val_iou_thresholded: 0.0204
# Epoch 62/100
# 752/752 [==============================] - 598s 795ms/step - loss: 0.0421 - iou: 0.0093 - iou_thresholded: 0.0093 - val_loss: 0.0290 - val_iou: 0.0102 - val_iou_thresholded: 0.0102
# Epoch 63/100
# 752/752 [==============================] - 598s 795ms/step - loss: 0.0244 - iou: 0.0124 - iou_thresholded: 0.0125 - val_loss: 0.0228 - val_iou: 0.0137 - val_iou_thresholded: 0.0137
# Epoch 64/100
# 752/752 [==============================] - 601s 800ms/step - loss: 0.0147 - iou: 0.0101 - iou_thresholded: 0.0102 - val_loss: 0.0149 - val_iou: 0.0070 - val_iou_thresholded: 0.0071
# Epoch 65/100
# 752/752 [==============================] - 599s 796ms/step - loss: 0.0106 - iou: 0.0113 - iou_thresholded: 0.0114 - val_loss: 0.0102 - val_iou: 0.0289 - val_iou_thresholded: 0.0293
# Epoch 66/100
# 752/752 [==============================] - 599s 796ms/step - loss: 0.0108 - iou: 0.0139 - iou_thresholded: 0.0143 - val_loss: 0.0090 - val_iou: 0.0035 - val_iou_thresholded: 0.0035
# Epoch 67/100
# 752/752 [==============================] - 598s 796ms/step - loss: 0.0046 - iou: 0.0134 - iou_thresholded: 0.0139 - val_loss: 0.0062 - val_iou: 0.0023 - val_iou_thresholded: 0.0024
# Epoch 68/100
# 752/752 [==============================] - 599s 796ms/step - loss: 0.0031 - iou: 0.0208 - iou_thresholded: 0.0218 - val_loss: 0.0057 - val_iou: 0.1366 - val_iou_thresholded: 0.1518
# Epoch 69/100
# 752/752 [==============================] - 598s 795ms/step - loss: 0.0022 - iou: 0.0195 - iou_thresholded: 0.0211 - val_loss: 0.0038 - val_iou: 0.0069 - val_iou_thresholded: 0.0078
# Epoch 70/100
# 752/752 [==============================] - 602s 801ms/step - loss: 0.0016 - iou: 0.0237 - iou_thresholded: 0.0274 - val_loss: 0.0037 - val_iou: 0.0355 - val_iou_thresholded: 0.0426
# Epoch 71/100
# 752/752 [==============================] - 599s 796ms/step - loss: 11479.2227 - iou: 0.0981 - iou_thresholded: 0.1017 - val_loss: 21157.7285 - val_iou: 0.4069 - val_iou_thresholded: 0.4069
# Epoch 72/100
# 752/752 [==============================] - 597s 794ms/step - loss: 1036.4860 - iou: 0.0821 - iou_thresholded: 0.0821 - val_loss: 182.1614 - val_iou: 0.0393 - val_iou_thresholded: 0.0393
# Epoch 73/100
# 752/752 [==============================] - 598s 795ms/step - loss: 63.8982 - iou: 0.0480 - iou_thresholded: 0.0480 - val_loss: 42.3001 - val_iou: 0.0185 - val_iou_thresholded: 0.0185
# Epoch 74/100
# 752/752 [==============================] - 598s 795ms/step - loss: 44.2199 - iou: 0.1075 - iou_thresholded: 0.1075 - val_loss: 43.8453 - val_iou: 0.0544 - val_iou_thresholded: 0.0544
# Epoch 75/100
# 752/752 [==============================] - 598s 795ms/step - loss: 15.9880 - iou: 0.0673 - iou_thresholded: 0.0673 - val_loss: 11.4476 - val_iou: 0.0049 - val_iou_thresholded: 0.0049
# Epoch 76/100
# 752/752 [==============================] - 601s 800ms/step - loss: 9.8820 - iou: 0.0598 - iou_thresholded: 0.0598 - val_loss: 6.8366 - val_iou: 0.1297 - val_iou_thresholded: 0.1297
# Epoch 77/100
# 752/752 [==============================] - 598s 796ms/step - loss: 63.2561 - iou: 0.0989 - iou_thresholded: 0.0989 - val_loss: 6.1306 - val_iou: 0.2249 - val_iou_thresholded: 0.2249
# Epoch 78/100
# 752/752 [==============================] - 598s 796ms/step - loss: 2.5092 - iou: 0.0179 - iou_thresholded: 0.0179 - val_loss: 1.1109 - val_iou: 0.0042 - val_iou_thresholded: 0.0042
# Epoch 79/100
# 752/752 [==============================] - 598s 795ms/step - loss: 0.9163 - iou: 0.0168 - iou_thresholded: 0.0168 - val_loss: 0.6793 - val_iou: 0.0264 - val_iou_thresholded: 0.0264
# Epoch 80/100
# 752/752 [==============================] - 598s 796ms/step - loss: 0.4141 - iou: 0.0199 - iou_thresholded: 0.0198 - val_loss: 0.3458 - val_iou: 0.0273 - val_iou_thresholded: 0.0274
# Epoch 81/100
# 752/752 [==============================] - 598s 796ms/step - loss: 77815.4375 - iou: 0.1443 - iou_thresholded: 0.1443 - val_loss: 1598.3969 - val_iou: 0.0508 - val_iou_thresholded: 0.0508
# Epoch 82/100
# 752/752 [==============================] - 600s 799ms/step - loss: 693.6120 - iou: 0.0175 - iou_thresholded: 0.0175 - val_loss: 430.1577 - val_iou: 0.3576 - val_iou_thresholded: 0.3576
# Epoch 83/100
# 752/752 [==============================] - 599s 796ms/step - loss: 273.4793 - iou: 0.0564 - iou_thresholded: 0.0564 - val_loss: 132.8708 - val_iou: 0.0077 - val_iou_thresholded: 0.0077
# Epoch 84/100
# 752/752 [==============================] - 599s 796ms/step - loss: 93.6768 - iou: 0.0240 - iou_thresholded: 0.0240 - val_loss: 71.4098 - val_iou: 0.0073 - val_iou_thresholded: 0.0073
# Epoch 85/100
# 752/752 [==============================] - 598s 795ms/step - loss: 65.8543 - iou: 0.0702 - iou_thresholded: 0.0702 - val_loss: 44.6662 - val_iou: 0.0037 - val_iou_thresholded: 0.0037
# Epoch 86/100
# 752/752 [==============================] - 599s 796ms/step - loss: 179.5319 - iou: 0.0505 - iou_thresholded: 0.0505 - val_loss: 33.7279 - val_iou: 0.0085 - val_iou_thresholded: 0.0085
# Epoch 87/100
# 752/752 [==============================] - 599s 797ms/step - loss: 68.0425 - iou: 0.0555 - iou_thresholded: 0.0555 - val_loss: 30.2426 - val_iou: 0.1408 - val_iou_thresholded: 0.1408
# Epoch 88/100
# 752/752 [==============================] - 601s 799ms/step - loss: 16.0966 - iou: 0.0190 - iou_thresholded: 0.0190 - val_loss: 12.3674 - val_iou: 0.0071 - val_iou_thresholded: 0.0071
# Epoch 89/100
# 752/752 [==============================] - 599s 796ms/step - loss: 15.7866 - iou: 0.0252 - iou_thresholded: 0.0252 - val_loss: 9.8787 - val_iou: 0.0207 - val_iou_thresholded: 0.0207
# Epoch 90/100
# 752/752 [==============================] - 598s 796ms/step - loss: 8.7081 - iou: 0.0144 - iou_thresholded: 0.0144 - val_loss: 6.8840 - val_iou: 0.0152 - val_iou_thresholded: 0.0152
# Epoch 91/100
# 752/752 [==============================] - 599s 797ms/step - loss: 2.4427 - iou: 0.0127 - iou_thresholded: 0.0127 - val_loss: 5.0633 - val_iou: 0.0025 - val_iou_thresholded: 0.0025
# Epoch 92/100
# 752/752 [==============================] - 598s 796ms/step - loss: 7269.5488 - iou: 0.1476 - iou_thresholded: 0.1476 - val_loss: 47.6973 - val_iou: 0.0021 - val_iou_thresholded: 0.0021
# Epoch 93/100
# 752/752 [==============================] - 599s 796ms/step - loss: 22.1597 - iou: 0.0238 - iou_thresholded: 0.0238 - val_loss: 7.9315 - val_iou: 0.0090 - val_iou_thresholded: 0.0090
# Epoch 94/100
# 752/752 [==============================] - 599s 797ms/step - loss: 5.2560 - iou: 0.0085 - iou_thresholded: 0.0085 - val_loss: 5.2969 - val_iou: 0.0228 - val_iou_thresholded: 0.0228
# Epoch 95/100
# 752/752 [==============================] - 599s 796ms/step - loss: 2.1628 - iou: 0.0086 - iou_thresholded: 0.0086 - val_loss: 1.6629 - val_iou: 0.0106 - val_iou_thresholded: 0.0106
# Epoch 96/100
# 752/752 [==============================] - 599s 796ms/step - loss: 1.7328 - iou: 0.0090 - iou_thresholded: 0.0090 - val_loss: 0.9798 - val_iou: 0.0135 - val_iou_thresholded: 0.0135
# Epoch 97/100
# 752/752 [==============================] - 598s 796ms/step - loss: 2474.7461 - iou: 0.2009 - iou_thresholded: 0.2009 - val_loss: 58.5075 - val_iou: 0.0058 - val_iou_thresholded: 0.0058
# Epoch 98/100
# 752/752 [==============================] - 598s 796ms/step - loss: 20.4486 - iou: 0.0071 - iou_thresholded: 0.0071 - val_loss: 5.1925 - val_iou: 0.0037 - val_iou_thresholded: 0.0037
# Epoch 99/100
# 752/752 [==============================] - 599s 797ms/step - loss: 3.5164 - iou: 0.0082 - iou_thresholded: 0.0082 - val_loss: 1.8617 - val_iou: 0.0120 - val_iou_thresholded: 0.0120
# Epoch 100/100
# 752/752 [==============================] - 599s 797ms/step - loss: 1.6494 - iou: 0.0115 - iou_thresholded: 0.0115 - val_loss: 0.8586 - val_iou: 0.0114 - val_iou_thresholded: 0.0114

# %%
from keras_unet.utils import plot_segm_history

plot_segm_history(history)

# %%
y_pred = model.predict(X_val)

# %%
from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=X_val, mask_imgs=y_val, pred_imgs=y_pred, nm_img_to_plot=10)

# %%
loss, iou, iou_thresholded = model.evaluate(X_val, y_val)
# Out:
# 90/90 [==============================] - 45s 457ms/step - loss: 0.8585 - iou: 0.0047 - iou_thresholded: 0.0047
