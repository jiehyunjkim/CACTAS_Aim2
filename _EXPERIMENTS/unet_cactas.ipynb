# %%
from unet_wrapper import unet_wrapper

# %%
U = unet_wrapper("/Users/jiehyun/Jenna/UMassBoston/Research/Nathan_Arnett_Calcification/images.npy", 
"/Users/jiehyun/Jenna/UMassBoston/Research/Nathan_Arnett_Calcification/labels.npy")

# %%
x, y = U.load_npy()
# Out:
# (503, 512, 512) (503, 512, 512)
# (503, 512, 512, 1) (503, 512, 512, 1)

# %%
model, x_val, y_val = U.train(x, y)
# Out:
# (512, 512, 1)
# Epoch 1/50
# 100/100 [==============================] - ETA: 0s - loss: 1.0000 - iou: 6.3085e-06 - iou_thresholded: 7.6869e-06 - dice_coef: 8.2233e-06 - accuracy: 0.6034 - sparse_categorical_accuracy: 0.9996
# Epoch 1: val_loss improved from inf to 0.99999, saving model to segm_model_v3.h5
# 100/100 [==============================] - 851s 9s/step - loss: 1.0000 - iou: 6.3085e-06 - iou_thresholded: 7.6869e-06 - dice_coef: 8.2233e-06 - accuracy: 0.6034 - sparse_categorical_accuracy: 0.9996 - val_loss: 1.0000 - val_iou: 5.1339e-06 - val_iou_thresholded: 1.0774e-05 - val_dice_coef: 9.6687e-06 - val_accuracy: 0.8999 - val_sparse_categorical_accuracy: 0.9998
# Epoch 2/50
# 100/100 [==============================] - ETA: 0s - loss: 1.0000 - iou: 1.3191e-05 - iou_thresholded: 2.5927e-05 - dice_coef: 1.7573e-05 - accuracy: 0.8763 - sparse_categorical_accuracy: 0.9996
# Epoch 2: val_loss improved from 0.99999 to 0.99999, saving model to segm_model_v3.h5
# ...

# %%
a_binary = U.predict(model, x_val)
# Out:
# 7/7 [==============================] - 196s 28s/step

# %%
plot = U.plot_resuts(a_binary, x_val, y_val)
